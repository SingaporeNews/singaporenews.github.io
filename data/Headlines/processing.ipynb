# %%
import pandas as pd
import nltk as nltk
from nltk.corpus import stopwords
import glob
import scipy as scipy
import collections

# %%
allFiles = glob.glob("*.txt")
df = pd.DataFrame()
#list = []
for files in allFiles:
    frame = pd.read_table(files)
    df = df.append(frame, ignore_index=True)

df = df.dropna()

# %%
df['tokens'] = df.Headline.apply(lambda x: nltk.word_tokenize(x.lower()))

# %%
df['tokens'] = df.tokens.apply(lambda x: [word.translate(None, "!@#$;':-*^&") for word in x])

# %%
replacements = [
                ("s'pore","singapore"),
                ("govt", "government"),
                ("pts", "points"),
                ]

# %%
def version_replace(x, replacements):
    for item in replacements:
        if x == item[0]:
            x = item[1]
        else:
            x = x
    return x

# %%
english_stops = set(stopwords.words('english'))
english_stops.discard('up')
english_stops.discard('down')
english_stops.add('...')
english_stops.add("'s")
english_stops.add('mr.')
english_stops.add("n't")
english_stops.add("'")
english_stops.add(":")

# %%
df['tokens'] = df['tokens'].apply(lambda x: [word for word in x if word not in english_stops and len(word) > 1])
df['tokens'] = df['tokens'].apply(lambda x: [version_replace(word, replacements) for word in x])

# %%
df58 = df[df.year == '1958']

# %%
fd = nltk.FreqDist([word for sent in df['tokens'] for word in sent])

# %%
word = []
count = []
for num, i in enumerate(fd.keys()[:100]):
    word.append(i)
    count.append(fd.values()[num])
    
freqData = pd.DataFrame()
freqData['words'] = word
freqData['count'] = count

# %%
freqData
# Out:
#          words  count
# 0          new     95
# 1          man     76
# 2       police     76
# 3           up     69
# 4       malaya     68
# 5    singapore     68
# 6       tengku     65
# 7          two     62
# 8        polio     58
# 9          big     54
# 10         men     52
# 11      strike     50
# 12         lim     48
# 13       talks     48
# 14         may     47
# 15       crash     46
# 16        reds     46
# 17          us     46
# 18         red     43
# 19        held     41
# 20        dies     40
# 21        fire     40
# 22      colony     39
# 23  government     39
# 24        says     37
# 25      killed     34
# 26         war     34
# 27       death     33
# 28          mr     33
# 29        plan     33
# 30        back     32
# 31     jakarta     31
# 32         tin     31
# 33      rebels     30
# 34      rubber     29
# 35     another     28
# 36        call     28
# 37       cases     28
# 38        four     28
# 39         die     27
# 40        goes     27
# 41      attack     26
# 42          go     26
# 43          nt     26
# 44       plane     26
# 45       three     26
# 46        hurt     25
# 47        ship     25
# 48         ban     24
# 49         get     24
# 50        king     24
# 51       trade     24
# 52         bid     23
# 53         boy     23
# 54         mac     23
# 55        quit     23
# 56       rebel     23
# 57     workers     23
# 58    alliance     22
# 59     council     22
#            ...    ...
#
# [100 rows x 2 columns]

# %%
df['year'] = df['Date'].apply(lambda x: str(x)[:4])

# %%
df58.head()
# Out:
#            Date                                           Headline  \
# 10761  19580101                          MINES CRISIS: A BIG PROBE
# 10762  19580101               TAXES HAUL  BRITISH FLAG  FROM SHIPS
# 10763  19580101  Gunboat waiting  off Colony  to seize  Dutch s...
# 10764  19580101                 Shoal off Colony traps second ship
# 10765  19580101         MERDEKA, SO FEDERATION GETS ONLY 14 TITLES
#
#                                                tokens  year
# 10761                     [mines, crisis, big, probe]  1958
# 10762             [taxes, haul, british, flag, ships]  1958
# 10763  [gunboat, waiting, colony, seize, dutch, ship]  1958
# 10764            [shoal, colony, traps, second, ship]  1958
# 10765         [merdeka, federation, gets, 14, titles]  1958
#
# [5 rows x 4 columns]

# %%
'''
yearDict = dict()
for year in df.year:
    if year in yearDict:
        continue
    else:
        yearDict[year] = 0
'''

wordDict = dict()
for row in df.tokens:
    for word in row:
        if word in wordDict:
            continue
        else:
            wordDict[word] = dict()

# %%
for num, row in enumerate(df.tokens[:1]):
    for word in row:
        year = df.year[num]
        if word in wordDict:
            if year in wordDict[word]:
                print type(wordDict[word])
                print wordDict[word][year]
# Out:
# <type 'dict'>
# 0
# <type 'dict'>
# 0
# <type 'dict'>
# 0

# %%
for row in range(len(freqData)):
    word = freqData['words'][row]
    word_count = freqData['count'][row]
    wordDict[word]['1958'] = word_count

# %%
wordDict['man']
# Out:
# {'1958': 76}

# %% [markdown]
# #### Co-occurrence Matrix

# %%
def cooccurence_matrix_corpus(corpus):
    matrix = collections.defaultdict(lambda : collections.defaultdict(int))
    
    for corpora in corpus:
        for i in xrange(len(corpora)-1):
            for j in xrange(i+1, len(corpora)):
                word1, word2 = [corpora[i], corpora[j]]
                matrix[word1][word2] += 1
                matrix[word1][word2] += 1
    return matrix

# %%
ccm = cooccurence_matrix_corpus(df['tokens'])

# %%
ccm['index']
# Out:
# defaultdict(<type 'int'>, {'45': 2, '36': 4, '1.156': 2, '1,800': 2, 'regional': 2, 'twoyear': 2, 'fall': 8, 'years': 6, 'leads': 2, '15.61': 2, '46point': 2, '3,000': 2, '7.5': 2, '2,200': 2, '12.9': 2, '32': 2, 'line': 4, 'move': 2, '700mark': 2, '10.1': 2, 'nearer': 2, 'buyers': 4, '10.12': 2, '20': 24, '21': 12, '22': 14, '23': 10, 'nervous': 2, '28': 14, '12.85': 2, 'fund': 2, 'good': 2, 'signals': 2, 'institutional': 2, 'breaches': 8, '16.3': 2, '400': 4, '33.41': 2, 'breach': 2, '25pt': 2, 'momentum': 2, 'lack': 2, 'return': 4, 'gains': 28, 'stay': 4, '10': 36, 'rules': 2, 'breaks': 14, 'continues': 8, '800level': 2, '26.68': 2, 'break': 2, 'next': 2, '12': 16, 'worst': 2, 'nearly': 6, '800pt': 4, 'sheds': 18, '25.38': 2, 'chips': 4, 'day': 6, 'cross': 2, '58': 4, '13.7': 2, 'loss': 2, '1400': 2, 'shattered': 2, '9.04': 2, 'level': 26, '55': 2, 'january': 2, 'drop': 4, '50': 2, '53': 2, 'slide': 6, '25': 4, 'bounces': 2, '54': 2, 'alltime': 24, 'stays': 2, 'dip': 2, 'heavy': 2, 'poor': 2, 'pane1': 2, 'interest': 2, '800mark': 4, '66': 2, '30point': 2, '18.79': 2, 'declines': 4, '1,044': 2, 'inching': 2, '700': 6, 'back': 2, 'slowdown': 2, 'past': 18, '2.9': 2, 'street': 6, 'trading': 14, 'year': 12, 'close': 4, 'news': 2, 'rebounds': 2, 'dives': 2, 'profittaking': 4, '84': 2, 'blue': 4, 'closes': 6, '31.34': 2, '10.67': 2, 'revised': 2, '792': 2, 'rate': 2, 'fourth': 2, '900level': 2, '13.52': 2, 'since': 4, '1,100pt': 2, 'looking': 2, '27': 8, '1,976.09': 2, '17pt': 2, 'postcrash': 6, 'goes': 8, '11.67': 2, 'new': 56, 'firms': 2, '4year': 2, 'jumps': 26, '1,600': 2, 'thin': 2, '24': 6, '30month': 4, 'earlier': 2, 'barrier': 12, 'slight': 2, 'climbs': 4, '2,100pt': 2, '912.28': 2, 'weak': 2, '26': 12, '27.3': 2, '47': 2, '16.43': 2, '11.86': 2, 'hectic': 2, '10.5': 4, 'buy': 2, 'rises': 18, 'abroad': 2, 'released': 2, '22.07': 2, '900': 10, 'plunges': 36, '19.61': 2, '33': 6, 'many': 2, 'months': 12, '750mark': 2, 'days': 2, '35': 6, '34': 14, '11.78': 2, 'massive': 2, '1,000point': 2, 'almost': 2, '23.9': 2, 'first': 6, 'managers': 2, 'wall': 8, '27.46': 2, '2,000': 10, 'zooms': 2, 'increased': 2, '11.11': 4, 'down': 92, '62': 2, '64': 2, '65': 2, 'another': 32, 'away': 2, '18month': 2, 'shoots': 4, 'lags': 2, '16.97': 4, 'punters': 2, 'market': 2, 'second': 2, '1,400': 8, 'passes': 12, 'fed': 2, '1,850': 2, 'takes': 6, 'puts': 2, '970': 2, 'support': 2, 'two': 2, 'mark': 36, 'retreats': 2, 'pc': 4, '24pt': 2, '8month': 2, 'low': 14, 'way': 2, '34.6': 2, '13.36': 2, '1,200': 2, 'markets': 4, 'bluechip': 2, '500': 2, 'lowest': 4, '12.28': 2, 'selling': 8, '1,922.89': 2, '650': 2, 'owest': 2, '39': 2, 'dips': 12, 'surges': 18, 'hits': 46, '2,400': 2, 'volume': 6, 'biggest': 6, 'wake': 2, '900mark': 4, 'demand': 4, 'prices': 2, 'despite': 2, 'highest': 6, 'reel': 2, '3month': 2, 'buying': 6, 'oneday': 4, '11': 40, 'jump': 2, '13': 18, 'crosses': 4, '15': 18, '14': 8, '17': 22, '16': 28, '19': 10, '18': 10, 'straight': 2, '31.62': 2, 'up': 178, 'hike': 2, 'record': 16, 'near': 2, 'nine': 2, '24.76': 2, 'turnover': 2, '31.68': 2, 'closing': 2, 'drops': 72, '1,878': 2, '400mark': 2, 'slips': 10, '30': 2, 'sees': 2, '600': 2, 'investors': 4, 'soars': 28, 'reacts': 2, 'december': 2, '26.9': 2, '1,500': 2, 'quiet': 4, 'high': 86, 'plunge': 8, 'firm': 2, 'rally': 2, '10.02': 2, 'hit': 8, 'blasts': 2, '400barrier': 2, '17.43': 2, 'reaches': 2, 'moves': 2, 'recovery': 2, '49': 2, '950': 4, '11.6': 2, '11.7': 2, '42': 2, '43': 2, '40': 2, '11.3': 2, '800points': 2, '1,300': 4, 'tumbles': 2, '10.99': 2, 'rupiah': 2, 'panic': 2, '11.21': 4, '1,370': 2, 'higher': 2, 'week': 2, '34.98': 2, 'extended': 2, 'crashes': 2, 'may': 2, 'dive': 2, 'time': 2, 'tops': 2, 'yesterday': 2, '38.24': 2, 'falls': 48, '15.57': 2, '25.4': 2, 'leaps': 6, 'peak': 10, '14.25': 2, '14.27': 2, '29': 8, '1,950': 2, '9.60': 2, 'rebound': 4, 'slides': 4, 'tokyo': 6, 'suffers': 4, '35.94': 2, 'third': 4, 'records': 2, 'light': 2, '16.66': 2, '31point': 2, 'cpf':  ...

# %%
ccm_dict = []
for node in ccm:
    datadict = {}
    if type(node) == str:
        datadict['name'] = node
        word_list = []
        #datadict[node] = []
        counter = 0;
        for item in ccm[node].items():
            #d = {}
            #d['name'] = item[0]
            #d['size'] = item[1]
            #datadict[node].append(d)
            counter += item[1]
            word_list.append(item[0])
        datadict['links'] = word_list
        datadict['size'] = counter
    ccm_dict.append(datadict)

# %%
ccm.keys()
# Out:
# [0,
#  1,
#  '1,800',
#  'deferment',
#  'vani',
#  'woods',
#  'spiders',
#  'hanging',
#  'woody',
#  'spidery',
#  'sevens',
#  'canes',
#  'opener',
#  'caned',
#  'onlinedrug',
#  'terazza',
#  'minials',
#  'terendak',
#  'offduty',
#  'exchief',
#  'screaming',
#  'wooden',
#  'broiled',
#  'ruiqi',
#  'innopac',
#  'lossmaking',
#  '270',
#  'bannister',
#  'singapore\xe2\x80\x94tengku',
#  'selassie',
#  'gorman',
#  '277',
#  '278',
#  '279',
#  'sporemalaysia',
#  'mdate',
#  'deferred',
#  'cooking',
#  'welfarism',
#  'curbfree',
#  'designing',
#  'replaced',
#  'shocks',
#  'chalkandfalk',
#  '27m',
#  'china',
#  'carcia',
#  'qucmoy',
#  'kids',
#  'climbed',
#  'controversy',
#  'ueber',
#  'redevelopment',
#  'climber',
#  'golden',
#  'schoolboy.',
#  'spanishasean',
#  'unsinkable',
#  'stern',
#  'agassi',
#  'dna',
#  'catchy',
#  'cannibal',
#  'inevitable',
#  'music',
#  '7ft',
#  'borstal',
#  'takle',
#  'demoted',
#  'yahoo',
#  'tilting',
#  'exco',
#  'schoolboys',
#  'intake',
#  'locked',
#  'kampala',
#  'nakasone',
#  'matilda',
#  'wang',
#  'few\xe2\x80\x94',
#  'pints',
#  'unjust',
#  '117g',
#  'want',
#  'cookers',
#  'absolute',
#  'travel',
#  'inside\xe2\x80\x94a',
#  'cutback',
#  'resistancestill',
#  'flossie',
#  'blankspace',
#  'dinosaurs',
#  'wrong',
#  'seda',
#  'sentencing',
#  'bombby',
#  'falkover',
#  'kuching',
#  'singapor',
#  'fishhead',
#  '18th',
#  'cratuity',
#  'welcomed',
#  'onejudge',
#  'kompong',
#  '620',
#  'minibond',
#  'rewarded',
#  'takeshita',
#  'welcomes',
#  'fir',
#  'fit',
#  'crosses\xe2\x80\x94now',
#  'lifeline',
#  'bringing',
#  'fix',
#  'secede',
#  'uob',
#  'fig',
#  'storedvalue',
#  'fin',
#  'bankrupts',
#  'uol',
#  'malay\xe2\x80\x94the',
#  'vouchers',
#  'basics',
#  'effects',
#  'sixteen',
#  'saddened',
#  'nineemperor',
#  'bartok',
#  'barton',
#  'musang',
#  'foregin',
#  'arrow',
#  'ingrid',
#  'burial',
#  'telescope',
#  'allah',
#  'allan',
#  'fourmillion',
#  '393',
#  '392',
#  '390',
#  '395',
#  '2day',
#  'allay',
#  'stabilised',
#  '120,000',
#  'touts',
#  'smirk',
#  'mason',
#  'encourage',
#  'adapt',
#  'outburst',
#  'abbott',
#  'stamping',
#  '3,181',
#  'heintoshe',
#  'estimate',
#  'universally',
#  'chlorine',
#  'gigarette',
#  'ministries',
#  'disturbed',
#  'portmanteau',
#  'tinal',
#  'popularise',
#  'nsfwith',
#  'kfc',
#  'colourcoordinated',
#  'viets',
#  'seizures',
#  'traction',
#  'olds',
#  'renovated',
#  'service',
#  'needed',
#  'master',
#  'sisir',
#  'rewards',
#  '48hr.',
#  'antihepatitis',
#  'doreen',
#  'mutilated',
#  'delifrance',
#  'positively',
#  'firstgame',
#  'feasibility',
#  '271',
#  'awacs',
#  'handcuffs',
#  'idle',
#  'ussies',
#  'feeling',
#  'firstquarter',
#  '\xe2\x80\x94one',
#  'increment',
#  'pomp',
#  'sailed',
#  'dozen',
#  'affairs',
#  'sitin',
#  'mostly',
#  'racers',
#  'snitch',
#  'kremlin',
#  'shipments',
#  'myth\xe2\x80\x94by',
#  'houseformoney',
#  'swiss',
#  'sarikei',
#  'mouth',
#  'euniversity',
#  'singer',
#  'merdeka\xe2\x80\x94seen',
#  'tecs',
#  'multiracial',
#  'agadir',
#  'fugitives',
#  'teck',
#  '2.7b',
#  'affair.',
#  'scream',
#  'saying',
#  '543,000',
#  'tempter',
#  'jttu',
#  '23,825',
#  'ulcer',
#  'tempted',
#  'thai',
#  'orleans',
#  'faure',
#  'clicked',
#  'excavator',
#  'needed\xe2\x80\x94a',
#  'rico',
#  'rich',
#  'grende',
#  'rice',
#  'rica',
#  'plate',
#  'throuqh',
#  'altogether',
#  'jaguar',
#  '\xc2\xa3120,000',
#  'nicely',
#  'boarder',
#  'patch',
#  'openly',
#  'stunts',
#  'optimism',
#  '30page',
#  'billand',
#  'clarifies',
#  'lots',
#  'irs',
#  'irk',
#  'ira',
#  'ird',
#  'wage',
#  'tipoffs',
#  'nature',
#  'off\xe2\x80\x94after',
#  'brainwashed',
#  '19581011',
#  'dunhill',
#  'gobble',
#  'cambodianthai',
#  'tyranny',
#  'japanasean',
#  '19581012',
#  'rumourmonger',
#  'powersharing',
#  'miyake',
#  'heating',
#  'incense',
#  'fruity',
#  '20cent',
#  '19581016',
#  'rehash',
#  'libsocs',
#  'maclaine',
#  '28year',
#  'atest.',
#  '4.2',
#  'basque',
#  'blonde',
#  'angioplasty',
#  'union',
#  'muck',
#  'much',
#  'fry',
#  'mothball',
#  'tallest',
#  'kwangtung',
#  'freehold',
#  'davy',
#  'atests',
#  'doubts',
#  'spin',
#  'spil',
#  'wildcat',
#  'exdah',
#  'dusktodawn',
#  'employ',
#  'rescinds',
#  'haiphong',
#  '3.8m',
#  'majid',
#  'raayat',
#  'expat',
#  'kohl',
#  'expap',
#  'eighteen',
#  'waddell',
#  'aseaneu',
#  '5050',
#  'breakfast',
#  'hone',
#  'horseback9',
#  'hong',
#  'memoriam',
#  'sos\xe2\x80\x94then',
#  'remand',
#  'honk',
#  '3\xc2\xbd',
#  'split',
#  'hons',
#  '.1,000',
#  'wizzes',
#  'principals',
#  '42death',
#  'boiled',
#  'marches',
#  'frenchmen',
#  'boiler',
#  'supper',
#  'hon.',
#  'academic',
#  'stillness',
#  '13.1m',
#  'corporate',
#  'up\xe2\x80\x94u.s.',
#  'bellow',
#  'dtay',
#  'mcycle',
#  'hai',
#  'haj',
#  'ham',
#  'han',
#  'citycab',
#  'watercolour',
#  'mcnamara',
#  'beloved',
#  'har',
#  'hat',
#  'haw',
#  'municipal',
#  'osman',
#  'elders',
#  'survival',
#  'silverwing',
#  'gobetween',
#  'exforeign',
#  'shadow',
#  'hamas',
#  'relooking',
#  '9.600',
#  'alice',
#  'gurnam',
#  'festivities',
#  'unabashedly',
#  'beneficial',
#  'crowd',
#  'czech',
#  'mosques',
#  'crown',
#  'begin',
#  'captive',
#  'trapped\xe2\x80\x94a',
#  '52nd',
#  'bottom',
#  'lockdown',
#  'inhuman',
#  'riottorn',
#  'plucked',
#  'ecstasy',
#  '19581109',
#  '19581108',
#  '19581107',
#  '19581106',
#  '19581105',
#  '19581104',
#  '19581103',
#  '19581102',
#  '19581101',
#  'compensttion',
#  'narok',
#  'applicantsare',
#  'brigades',
#  'starring',
#  'fiveway',
#  'spaceships',
#  'aden',
#  'maxwell',
#  'marshall',
#  'honeymoon',
#  'mba',
#  'marshals',
#  'mbt',
#  'zond5',
#  'zond6',
#  'mbs',
#  '872,500',
#  'raped',
#  'despises',
#  'greatness',
#  'rapes',
#  '\xe2\x80\x94of',
#  'grooms',
#  'perfumes',
#  'shireen',
#  'jailed\xe2\x80\x94of',
#  'bugresistant',
#  'duel',
#  'arrays',
#  'aza',
#  'smashes',
#  'unanimous',
#  'servings',
#  'smashed',
#  'dues',
#  'pricing',
#  'passenger',
#  'over\xe2\x80\x94till',
#  'indiapak',
#  'disgrace',
#  'holdback',
#  'disperses',
#  'indiapax',
#  'voroshilov',
#  'triangles',
#  'eventual',
#  'crowns',
#  'pasadena',
#  'role',
#  'intrusions',
#  'roll',
#  'exouf',
#  'intend',
#  '5gold',
#  'devon',
#  'triangle9',
#  'nonformal',
#  'variable',
#  'sarsready',
#  'hawker',
#  'explosions',
#  'shootout',
#  'yenaf',
#  'yenan',
#  'stuntmr.',
#  'oba.',
#  'overturned',
#  'gown',
#  'chain',
#  'sporebased',
#  'm.p.injail',
#  'bandits',
#  'osa',
#  'chair',
#  'tampines',
#  'sinema\xe2\x80\x94by',
#  'ballet',
#  '690',
#  'grapples',
#  'tsiranana',
#  'exhigh',
#  'crates',
#  'crater',
#  'silencers',
#  'teamup',
#  'macho',
#  'choice',
#  'lark',
#  'mobilise',
#  'gloomy',
#  'stays',
#  'withchinegs',
#  'southpaw',
#  'exact',
#  'minute',
#  'cooks',
#  'cessna\xe2\x80\x94then',
#  'wedding\xc3\x82\xe2\x80\x94then',
#  '74,000',
#  'cooke',
#  'fathertobe',
#  'batsmen',
#  'picture\xe2\x80\x94govt.',
#  'meadow',
#  'trails',
#  'jumblatt',
#  'trisha',
#  'excerpts',
#  'bagging',
#  'abdullah',
#  'wayward',
#  '3avisit',
#  'geography',
#  'boost',
#  '1\xc3\x82\xc2\xbd',
#  'oldies',
#  'climbs',
#  'honour',
#  'plucking',
#  'gladys',
#  'address',
#  '3inarow',
#  'dusty',
#  '1900mile',
#  'mooncakes',
#  'airlift\xe2\x80\x94of',
#  'out\xe2\x80\x94by',
#  'queue',
#  'abducted.',
#  'indonesianchinese',
#  'enrols',
#  'vituperation',
#  'instal',
#  'ampil',
#  'berjaya',
#  'abase',
#  'opposes',
#  'working',
#  'hyatt',
#  'vigour',
#  'opposed',
#  'germanmalayan',
#  'pillow',
#  'philippjnes',
#  'sierra',
#  'consoles',
#  '94th',
#  'riders',
#  'sportsgirls',
#  'abortion',
#  'albright',
#  'following',
#  '\xc2\xa31,033',
#  '55plus',
#  'admired',
#  'mirrors',
#  'seccond',
#  'parachute',
#  'locks',
#  'snowdons',
#  'usno',
#  'admires',
#  'admirer',
#  'listens',
#  'litre',
#  'septic',
#  'korbut',
#  'petrochem',
#  'guerillas',
#  'conscious',
#  'roomafter',
#  'swollen',
#  'skirmish',
#  'wolves',
#  'thundery',
#  'pulled',
#  'blowup',
#  'postcrash',
#  'below.',
#  'years',
#  'professors',
#  'yearn',
#  'yeara',
#  'dead9',
#  'jie',
#  'jia',
#  'jin',
#  'jim',
#  'troubles',
#  'medallist',
#  'jit',
#  'hambali',
#  'dead.',
#  'suspension',
#  'troubled',
#  'apron',
#  'recipients',
#  'civilian',
#  'retailer',
#  '8million',
#  'pinetree',
#  'year.',
#  'drilling',
#  '4day',
#  'probusiness',
#  '24.5',
#  'fisherman',
#  'instability',
#  'quarter',
#  'quartet',
#  'bursting',
#  'receipt',
#  'sponsor',
#  'entering',
#  'disasters',
#  'antisubversion',
#  'interned',
#  'seriously',
#  'trauma',
#  'internet',
#  'curbs',
#  'sporejapan',
#  'incentives',
#  'snooker',
#  'lucrative',
#  'disaster9',
#  'byte',
#  'workmanship',
#  '7,000mile',
#  'babskilled',
#  'modest',
#  'sharprebuke',
#  'the\xe2\x80\x94chances',
#  'aboard',
#  'socking',
#  'neglect',
#  'emotion',
#  'gunshot',
#  'onn',
#  'onl',
#  'spoken',
#  'francospore',
#  'ona',
#  'ong',
#  'reprisal',
#  'one',
#  'onq',
#  'ont',
#  'stayput',
#  'renal',
#  '4,200',
#  '1.54',
#  'shawn',
#  'surges',
#  'exceptioneven',
#  'snatch',
#  'shaws',
#  'superairliner',
#  'specialists',
#  'lelyveld',
#  '180ft.',
#  'crossroads',
#  'rehab',
#  'wandering',
#  '2496413',
#  'illness',
#  'sumptuous',
#  'turned',
#  'locations',
#  'jewels',
#  'nympho',
#  'minesweepers',
#  'turner',
#  'zoc',
#  'boyd',
#  'baggage',
#  'warriors',
#  'killersquad',
#  'zoo',
#  'intends',
#  'concern',
#  'murphy',
#  '18.5m',
#  'opposite',
#  'buffer',
#  'discerning',
#  'buffet',
#  'printed',
#  'siglap',
#  'knowingly',
#  'bolshoi',
#  'touchy',
#  'phil',
#  'jitters',
#  'jittery',
#  'lydia',
#  'spaceage',
#  'giap',
#  'wynn',
#  'peoplenow',
#  'shoddy',
#  'friction',
#  'smsstyle',
#  'subsidiary',
#  'qom',
#  'refuelling',
#  'kueh',
#  'coaxing',
#  '1.5b',
#  'guarded',
#  '9,500',
#  'tsakok',
#  'blachan',
#  'rejoices',
#  'etcetera',
#  'awaiting',
#  '46,464',
#  'whipped',
#  'choudhury',
#  'vision',
#  'happytobeback',
#  'doubledegree',
#  'sharebrokers',
#  'airlifts',
#  'rescueand',
#  '\xe2\x80\xa2faster',
#  '832',
#  '833',
#  'harvey',
#  'sponsorship',
#  'dr.k',
#  'enjoys',
#  'westy',
#  'tsui',
#  'pointby',
#  'awards',
#  'selfproclaimed',
#  'caas',
#  'concentrated',
#  'busting',
#  'rhodes',
#  'fiu',
#  'matheson',
#  'millionaire',
#  'workplace',
#  '3judge',
#  'tubbed',
#  'vaccine9',
#  'try\xe2\x80\x94and',
#  'allowance',
#  'loveliest',
#  'glutinous',
#  'gaiety',
#  'tulloh',
#  'buoyancy',
#  'collides',
#  'west',
#  'susilo',
#  'motives',
#  'biafra',
#  'preparesfor',
#  'wants',
#  'mekong',
#  'formed',
#  'photos',
#  'tightened',
#  '.the',
#  'milkpowder',
#  'former',
#  'squeezes',
#  'newspaper',
#  'situation',
#  'scats',
#  'mutineers',
#  'fabricating',
#  'engaged',
#  '12year',
#  'limping',
#  'engages',
#  'technology',
#  'pekemas',
#  'otto',
#  'coalitionbuilding',
#  'wires',
#  'assigns',
#  'singapore',
#  'defy',
#  'nononsense',
#  'singaporp',
#  'walesa',
#  'wired',
#  'advertisement',
#  'weightage',
#  'tracking',
#  '60,000',
#  'liberians',
#  'capitalist\xe2\x80\x94dr.',
#  'masks',
#  'dimension',
#  'cohesive',
#  'beind',
#  'oficebox',
#  'recycled',
#  'steamer',
#  'rover',
#  'tha\xe2\x80\x94the',
#  'grounded',
#  'excuses',
#  '26.68',
#  'plumed',
#  'overthrow',
#  'panjang',
#  'rejoin',
#  'assemblyman',
#  'sums',
#  'unveil',
#  'romps',
#  'traffic',
#  'preference',
#  'world',
#  'postal',
#  'medifund',
#  'sensational',
#  'funfilled',
#  'hunger.',
#  'hamiltons',
#  'shutter',
#  'g.o.c.',
#  '37.47',
#  'obstruct',
#  'satisfactory',
#  'superintendent',
#  'grub',
#  'forpedo',
#  'tvs',
#  'tvn',
#  'surtax',
#  'tve',
#  'vesco',
#  'divine',
#  'out7problem',
#  'seaman',
#  'finis\xc3\x82\xe2\x80\x94if',
#  'tossed',
#  'restoring',
#  'nudein',
#  'squabble',
#  'meestall',
#  'retains',
#  'tv3',
#  'windfalls',
#  'leadership',
#  '30sec.',
#  'spacelab',
#  'thailand',
#  'luxurious',
#  'cinebabe',
#  'overladen',
#  'stanleyville',
#  'neardrowning',
#  'rumpus',
#  'perturbed',
#  'choppers',
#  'tinand',
#  'lively',
#  'hoursafter',
#  'wit.',
#  'rossi',
#  'bubbly',
#  'mongers',
#  'off\xe2\x80\x94that',
#  'plan\xe2\x80\x94biggest',
#  'gleam',
#  'lounging',
#  'mindless',
#  'sealed',
#  'brazilian',
#  'bubble',
#  'weeps\xe2\x80\x94unable',
#  'saris',
#  'sarit',
#  'wits',
#  'backlane',
#  'lubis',
#  'dfigital',
#  'abused',
#  'pull',
#  'rush',
#  'miss.',
#  '71,000',
#  'rage',
#  'sisterhood',
#  'puasa',
#  'rags',
#  'dirty',
#  'abuser',
#  'abuses',
#  'trips',
#  'oneall',
#  'watches',
#  'watched',
#  'ecafe',
#  'tremble',
#  'dampens',
#  'cream',
#  'yoga',
#  'cooked',
#  'yogi',
#  'soekarno',
#  'unparalleled',
#  'bumperedition',
#  'carlorry',
#  'puppy',
#  'passerby',
#  '35,000',
#  'albar',
#  'midget',
#  'brotherhood',
#  'lightermen',
#  'observers',
#  'omnibus',
#  'firebrand',
#  'dyed',
#  'enrichment',
#  'curate',
#  'caused',
#  'beware',
#  'sca',
#  '\xe2\x80\x94for',
#  'scv',
#  'causes',
#  'lightup',
#  'predawn',
#  'cheney',
#  'hatoyama',
#  'riots',
#  'nora',
#  'vietcongstyle',
#  'tamils',
#  'robbess',
#  'aseaneec',
#  'ofthe',
#  'checkin',
#  'tassotti',
#  'floated',
#  'baton',
#  '24th',
#  'expats',
#  'banrose',
#  'sant',
#  'rootless',
#  'ploira',
#  'sang',
#  'sand',
#  'sane',
#  'small',
#  'sanh',
#  'quicker',
#  '198',
#  '195',
#  '194',
#  '197',
#  'manjit',
#  '190',
#  '193',
#  'past',
#  'pasu',
#  'healey',
#  'pasp',
#  '18m.',
#  'pass',
#  'investment',
#  'quicken',
#  'clock',
#  'ladakh',
#  'thaimalaysian',
#  'jurist',
#  'full',
#  'vvip',
#  '2bus',
#  '19m',
#  'ganda',
#  'civilians',
#  'november',
#  'thumbsup',
#  'hass',
#  'khmers',
#  'experience',
#  'prior',
#  'periodic',
#  'cessation',
#  'obiang',
#  'followed',
#  'romphilippines',
#  'reclaimed',
#  'bocelli',
#  'mohandas',
#  'ileto',
#  'matadi',
#  'kogam',
#  'up\xe2\x80\x94but',
#  'silva',
#  'attendance',
#  'mort',
#  'mr.f',
#  'mori',
#  'moro',
#  'automate',
#  'printer',
#  'door',
#  'bhichai',
#  'nomay',
#  'company',
#  'tested',
#  '4,900',
#  'doom',
#  '100tol',
#  'noman',
#  'vc10',
#  'godown',
#  'thickest',
#  'learn',
#  'knocked',
#  'konggo',
#  'scramble',
#  'natch',
#  'memoirs',
#  'cuts\xe2\x80\x94then',
#  'lesotho',
#  'sikh',
#  'bonded',
#  'huge',
#  'simpr',
#  'speedboat',
#  'hugh',
#  'dismissed',
#  'scifi',
#  'hugs',
#  'dismisses',
#  'intended',
#  'mendes',
#  'debate\xe2\x80\x94then',
#  'disgraced',
#  'mendez',
#  'lanka',
#  'segni\xe2\x80\x94slight',
#  'jiang',
#  'pigmy',
#  'twisting',
#  'ngame',
#  '11.5',
#  'paysc',
#  'starhub',
#  'installed',
#  'resorts',
#  'scots',
#  'scott',
#  'replies',
#  'smiling',
#  'roots',
#  'revalued',
#  'bangla',
#  'hounds',
#  'plotters',
#  'bypass',
#  'micueast',
#  'sauce',
#  'revalues',
#  'colleague',
#  'abandons',
#  'entire',
#  'rajendra',
#  'gadget',
#  '191,000',
#  'idols',
#  'jordan.',
#  'mandarins',
#  'courses',
#  'repayment',
#  'facesaving',
#  'shocking',
#  'reactions',
#  'begged',
#  '\xc3\x82\xc2\xa3',
#  'redetained',
#  '524.5',
#  'advertisers',
#  'scotches',
#  'pea',
#  'granmininik',
#  'posbank',
#  'ernie',
#  'research',
#  'inquires',
#  'triennial',
#  'jiangsu',
#  '23point',
#  'bedlam',
#  'definition',
#  'pairs',
#  '60something',
#  'landak.',
#  'lawsuits',
#  '3,000plus',
#  'noordin',
#  '5.9b',
#  'firsts',
#  'our\xe2\x80\x94',
#  'bikeys',
#  'there\xe2\x80\x94an',
#  'benedict',
#  'exka',
#  'hallowed',
#  'sains',
#  'bedridden',
#  'saint',
#  'aver',
#  'olde',
#  'essays',
#  'subsidise',
#  'musa.',
#  'lifesciences',
#  'hushedup',
#  'typhoon',
#  'on\xe2\x80\x94to',
#  'condolences',
#  'getaway',
#  'tummy',
#  'banishees',
#  'prescott',
#  'nikolai',
#  'organisations',
#  'guarding',
#  'setat',
#  'graffiti',
#  'ccs',
#  'reorganisation',
#  'sell',
#  'extorted',
#  'self',
#  'also',
#  'jostle',
#  'sharpe',
#  'departmental',
#  'singles',
#  'tsafendas',
#  'mazenah',
#  'virus',
#  'singled',
#  'understands',
#  'arson',
#  'seize',
#  'sometimes',
#  'barred',
#  'bullseye',
#  'favell',
#  'barrel',
#  'phonetc',
#  'bulletin',
#  'wording',
#  'ugh',
#  'bookings',
#  'caruse',
#  'akarta',
#  'occupation',
#  'wraps',
#  'shahanaz',
#  'gooey',
#  'pap\xe2\x80\x94',
#  'cassette',
#  'westernstyle',
#  'crashlands',
#  'columns',
#  'kwali',
#  'dollahs',
#  'adventurers',
#  'sunny',
#  'selangor\xe2\x80\x94by',
#  'remedy',
#  'frenchman..',
#  'bridgeengine',
#  'amoks',
#  'pleasures',
#  'bytes',
#  'piped',
#  'tanker',
#  'insane',
#  '312',
#  '310',
#  '317',
#  '316',
#  '315',
#  'overboard',
#  'project',
#  'laotians',
#  'taximini',
#  'redsby',
#  '15th',
#  'malayanisation',
#  '90km',
#  'oneforfour',
#  'untouched',
#  '31m',
#  'condoned',
#  '31b',
#  'tion',
#  '7,756',
#  'last',
#  'swigert',
#  'connection',
#  'retarded',
#  'lash',
#  'hitsun',
#  'sadat',
#  'hiap',
#  '157,000',
#  'bell',
#  'golding',
#  'acted',
#  'giantkiller',
#  'society\xe2\x80\x94but',
#  'hian',
#  'belt',
#  'lender',
#  'dialacab',
#  'satire',
#  '\xe2\x80\x94another',
#  'manila.',
#  '\xc2\xa32m',
#  'adaptable',
#  'moderation',
#  'awake',
#  'consulate',
#  'presses',
#  '\xc2\xa320',
#  '\xc2\xa327',
#  '\xc2\xa325',
#  '\xc2\xa324',
#  'expanded',
#  'budget',
#  'admire',
#  '33',
#  'pressed',
#  '32',
#  'cages',
#  'year1967',
#  'xian',
#  'xiao',
#  'sitar',
#  'sfpmip',
#  'pacnet',
#  'cuisine',
#  'raiders',
#  'priorityby',
#  'yeti',
#  'flooded',
#  'kindergartens',
#  '6,898',
#  '26,000',
#  'deckeye',
#  '4.2120',
#  'vargas',
#  'climb',
#  'nabs',
#  'kng',
#  'zubir',
#  'thais',
#  'ltd.',
#  'foulup',
#  'scoffs',
#  'courting',
#  'transvision',
#  '220,500',
#  'hercules',
#  '3040',
#  '3045',
#  'swilling',
#  'cuffs',
#  'reap',
#  'jesselton',
#  'gains\xe2\x80\x94',
#  'pinball',
#  'fourdeath',
#  'parents',
#  'riskso',
#  'mandai',
#  'amusing',
#  'khun',
#  'cordon',
#  'indonesian',
#  'emergency',
#  'impaling',
#  'couple',
#  'wives',
#  'oneyear',
#  'abound',
#  'colonials',
#  'emergence',
#  'abduct',
#  'indonesias',
#  'spink',
#  'spine',
#  'suf',
#  'sukan',
#  'chorus',
#  'individuals',
#  'yoursfor',
#  'alexandra',
#  'spins',
#  'concedes',
#  'methods',
#  'bounce',
#  '62,000ton',
#  'mideast',
#  'greener',
#  'tisch',
#  'redstone',
#  'and/or',
#  'progovt',
#  'microbes',
#  'firecracker',
#  'gcmg',
#  'gateway',
#  'behave',
#  'seclusion',
#  'oact',
#  'hainanese',
#  'off\xe2\x80\x94in',
#  'othman',
#  'lowend',
#  'respite',
#  'eighthfloor',
#  'threemile',
#  'netbaliers',
#  'brotherrace',
#  'melbourne',
#  'deserves',
#  'car\xe2\x80\x94only',
#  'rm600m',
#  'offbudget',
#  'holesinthewall',
#  'terrorists',
#  'legalise',
#  'intq',
#  'controversies',
#  'jack.',
#  'inspects',
#  'curbs.',
#  'span',
#  'openg',
#  'sock',
#  'sithole',
#  'timesaving',
#  'spas',
#  'opens',
#  'debbie',
#  'barbirolli',
#  'jacks',
#  'hawaiian',
#  'peeper',
#  'baochai',
#  'jacky',
#  'deductions',
#  'barman',
#  'atlantic',
#  'jacko',
#  '\xc2\xbcmonth',
#  'peeped',
#  'charmed',
#  '30hour',
#  'timeoff',
#  'erica',
#  '\xe2\x80\xa2\xe2\x80\xa2\xe2\x80\xa2but',
#  'preemptive',
#  'charmer',
#  'retaliatory',
#  'huggett',
#  'chad',
#  'lowincome',
#  'chai',
#  'influence',
#  'haunt',
#  'rabat',
#  'itby',
#  'chap',
#  'diverse',
#  'chat',
#  '\xc2\xa3smil.',
#  'suppnegara',
#  'seafet\xe2\x80\x94the',
#  'intrepid',
#  '6.2b',
#  'puzzling',
#  'apprentices',
#  'uranium',
#  'wizoffice.com',
#  'hove',
#  '2.7m',
#  'revision',
#  'swaran',
#  '19580927',
#  'krease',
#  '19580928',
#  '19580929',
#  'lufthansa',
#  'lang',
#  'lane',
#  'land',
#  'lana',
#  'maradona',
#  'interdicted',
#  'purged',
#  'gunboats',
#  'lans',
#  'retailers',
#  '6.20',
#  'dawning',
#  'splashing',
#  'carowners',
#  'totem',
#  'broader',
#  'flashback',
#  'conservative',
#  'fallchance',
#  'detectives',
#  'turkish',
#  'horsing',
#  'h.r.',
#  'hints',
#  'resources',
#  'fenner',
#  'freind',
#  'petitions',
#  'gurion',
#  '491,000',
#  'essandoh',
#  'antiplo',
#  'fewer',
#  'damning',
#  'joscelin',
#  'leonardo',
#  'dockers',
#  '590',
#  'adm.',
#  '592',
#  'cannibals',
#  'z.a.',
#  'mishap',
#  'crook',
#  'video',
#  'victor',
#  'sweats',
#  'multimedia',
#  'turnaround',
#  'flowing',
#  'charade',
#  'vlets',
#  'playstation2',
#  'backjobless',
#  'fifteen',
#  'mccloskey',
#  'thath',
#  'badat',
#  'openbidding',
#  'fetch',
#  'quaint',
#  'survey',
#  'survivoramy',
#  'derby',
#  'makes',
#  'maker',
#  '1936',
#  'torchlight',
#  'panicked',
#  'steamers',
#  '7.50',
#  'yemenis',
#  '\xc3\x9cbin',
#  'pillion',
#  'striker\xe2\x80\x94',
#  'milelong',
#  'nibbling',
#  'confidence',
#  'dancethen',
#  'next',
#  '82cents',
#  'eleven',
#  'assuring',
#  'pfa',
#  'pencil',
#  'winemix',
#  'undeclared',
#  'babs',
#  '7.5m',
#  'baby',
#  'central',
#  '7.5b',
#  'iail',
#  'customer',
#  '17pt',
#  'integrating',
#  'clients',
#  'malinovsky',
#  'unknowns',
#  'reserves',
#  'stronggrowth',
#  'choi',
#  'rafflesians',
#  'embassywrecked',
#  'process',
#  'lock',
#  'coolness',
#  'rode',
#  'promotional',
#  'nears',
#  'zhuang',
#  'educational',
#  'burled',
#  'babyfirst',
#  'bilingual',
#  'comedy',
#  'intelligent',
#  'pales',
#  'chou',
#  'swearingin',
#  'subsummit',
#  'summonses',
#  'monoxide',
#  'pocket',
#  'manpower',
#  'robot',
#  'allfuxhou',
#  'thigh',
#  'mute',
#  'insight',
#  'directs',
#  'lifeordeath',
#  '12,800',
#  'perfect',
#  'teammp',
#  'thieves',
#  'stalled',
#  'hijackers',
#  'hijackert',
#  'sabotaging',
#  'a.m.round',
#  'prosper',
#  'prophetess',
#  'seawater',
#  'snake',
#  'insurance\xe2\x80\x94',
#  'ardaagony',
#  'tumourkiller',
#  'proopposition',
#  'scenic',
#  '70.79',
#  'preelection',
#  'peking',
#  'lifescience',
#  'shortage',
#  'involvement',
#  'scorch',
#  'glasses',
#  'otago',
#  'pahang\xe2\x80\x94yes',
#  'muchneeded',
#  'bump',
#  'bums',
#  'bumi',
#  'books',
#  'buma',
#  'witness',
#  'matrix',
#  'mindboggling',
#  'rigging',
#  'birthda',
#  'switchon',
#  'durban',
#  'cheong',
#  'greedy',
#  'mazita',
#  'durbar',
#  's.p.a.',
#  'chilli',
#  'mainland',
#  'hunks',
#  'gallons',
#  'could',
#  'chargewe',
#  'hiddencamera',
#  'chilly',
#  'repeats',
#  'relays',
#  'matthias',
#  'scene',
#  'soothing',
#  'khans',
#  'scent',
#  'guni',
#  'vetoed',
#  'festival',
#  'wins.',
#  'backdoor',
#  'sergeant',
#  'vetoes',
#  'interests',
#  'vigorous',
#  'quarry',
#  'chong',
#  'poached',
#  'roulette',
#  'loytape',
#  'quadruplets',
#  'charttoppers',
#  'dosai',
#  'false',
#  'shrinks',
#  'chelsia',
#  'ponders',
#  'cecil',
#  'dishes',
#  'sinatra',
#  'worldwide',
#  'tonight',
#  'manor',
#  'caught\xe2\x80\x94p.',
#  'fiiel',
#  'drugcrazed',
#  'cipher',
#  'instil',
#  'tebuan',
#  'upanddown',
#  'thanksgiving',
#  'irp',
#  'consorting',
#  'brez',
#  'undersea',
#  'brew',
#  '60strong',
#  'scotts',
#  'ablast',
#  'taps',
#  'jay',
#  'jaw',
#  'jap',
#  'jan',
#  'exresident',
#  'syces',
#  'jam',
#  'tape',
#  'mmit',
#  'jag',
#  'sohappy',
#  'jab',
#  'abbe',
#  '2708475',
#  'abba',
#  'disarm',
#  'ananda',
#  'taxes',
#  'haris',
#  'stuff',
#  'logbook',
#  '37day',
#  'guessing',
#  'reykjavik',
#  'prises',
#  'frame',
#  'asean\xe2\x80\x94by',
#  '122,000',
#  'nnvuihere',
#  'airmail',
#  'destiny',
#  'insulting',
#  'nuclear',
#  'grimfaced',
#  'preminger',
#  'keynote',
#  'farewell\xe2\x80\x94then',
#  'tutut',
#  'lawsuit',
#  'move\xe2\x80\x94by',
#  'maznah',
#  'marts',
#  'bristow',
#  'keppel',
#  'doorway',
#  'keppei',
#  'klspore',
#  'boyer',
#  'roughed',
#  'thieuky',
#  'success\xe2\x80\x94',
#  'undergraduate',
#  'fusako',
#  'trishaman',
#  'kahn',
#  'feather',
#  'describe',
#  'commuter',
#  'uss\xe2\x80\x94by',
#  'sporeaustralia',
#  'multitier',
#  'rbs',
#  'reminiscence',
#  'podcasts',
#  'fielding',
#  'talkabouts',
#  'playgrounds',
#  'barita',
#  'securityspecial',
#  'speedtrap',
#  'ransom',
#  'tattoo',
#  'denial',
#  'offon',
#  '1.2m',
#  'dead\xe2\x80\x94is',
#  'gibbs',
#  '1,750',
#  'twoday',
#  'of_',
#  'identity',
#  'diabetes',
#  'karang',
#  'ofa',
#  'phasingout',
#  'pows',
#  'indonesia',
#  'phan',
#  'pham',
#  '1.28',
#  'fashionable',
#  'oft',
#  'cheapergrade',
#  '1.23',
#  'diversify',
#  'audio',
#  '1.25',
#  'stressed',
#  'newest',
#  'libyan',
#  '288,000',
#  'clocks',
#  'matsushita',
#  'web',
#  'wee',
#  'wed',
#  'wei',
#  'wen',
#  'wem',
#  'wet',
#  'enfield',
#  'practise',
#  'villagers',
#  'eateries',
#  'pied',
#  'normalise',
#  'putra',
#  'falters',
#  'crux',
#  'cruz',
#  'zimbabwe',
#  'mathematics',
#  '11.11',
#  'pier',
#  'pies',
#  'thrill',
#  'villagehides',
#  'become',
#  'bermudan',
#  'toppakistan',
#  'snooting',
#  '389,500',
#  'subic',
#  'viceconsul',
#  'choosina',
#  'pregnancy',
#  'dahomey',
#  'distracts',
#  'scatters',
#  'choosing',
#  'flush',
#  'recognition',
#  'contested',
#  'morris',
#  'sayonara',
#  'onthespot',
#  'biology',
#  'acmapei',
#  'nuts4',
#  'hooligan',
#  'pressure',
#  'imaginary',
#  'dogshooter',
#  'homemaker',
#  'lifestyle',
#  'langer',
#  '5oo',
#  'swimming',
#  'bottledup',
#  'letters',
#  's.t.',
#  'advert',
#  'gilliatt',
#  'pairing',
#  'watchman',
#  'terminates',
#  'yellowtop',
#  'but\xc3\x9fa',
#  'bagged',
#  'maori',
#  '100ft',
#  'moonstruck',
#  '31hour',
#  'maory',
#  'antigovt',
#  'places',
#  'excitement',
#  'placed',
#  'garbo',
#  'problem',
#  'nurses',
#  'girl\xe2\x80\x94for',
#  'deadly',
#  'saviour',
#  'details',
#  'behold',
#  'backed\xe2\x80\x94the',
#  'repeat',
#  'zhou',
#  'lauds',
#  'outlets',
#  'multinationals',
#  'repeal',
#  'exposure',
#  'searches',
#  'horses\xe2\x80\x94no',
#  'dave',
#  'compete',
#  'searched',
#  'guilty\xe2\x80\x94or',
#  'gardens',
#  'supermarts',
#  'nursery',
#  '2,200',
#  'kassem',
#  'integrity',
#  'cm.',
#  'porno',
#  'punjab',
#  'v.s.',
#  'xuanqui',
#  'neighbours',
#  'masayoshi',
#  'worth',
#  'permit\xe2\x80\x942',
#  '1,976',
#  '54m.',
#  'issers',
#  'samurai',
#  'deadline',
#  'acetylene',
#  'jamaica',
#  'stemcell',
#  'sabbath',
#  'tawau',
#  'crisislee',
#  'panda',
#  'machines',
#  'topup',
#  '10up',
#  'stardom',
#  'fluctuates',
#  'offshoots',
#  'petro',
#  '700picul',
#  'englandargentina',
#  'petra',
#  'scaleddown',
#  'sukarno',
#  'jolts',
#  'halfmast',
#  'protection',
#  'seast',
#  'threeroomers',
#  'sorceress',
#  'stresses',
#  'fourteen',
#  'less.',
#  'postpones',
#  'britain\xe2\x80\x94with',
#  'lonesome',
#  'postponed',
#  'nationaland',
#  'darlings',
#  'plenum',
#  'elections1',
#  'bra',
#  'sarah',
#  'plot',
#  'coins',
#  'bundles',
#  'bundled',
#  'sweated',
#  'exacts',
#  'abusing',
#  'pudu',
#  'regrouping',
#  'championships',
#  'allies',
#  'aseanec',
#  'fairdeal',
#  'blocking',
#  'tnt',
#  '1993',
#  'rumanian',
#  'erp',
#  'tnp',
#  'divorced',
#  '1996',
#  '1999',
#  '1998',
#  'honeymooners',
#  'tne',
#  'divorces',
#  'cuddle',
#  'era',
#  'elbow',
#  'tni',
#  'souring',
#  '9year',
#  'indicated',
#  '\xc2\xa3130m',
#  'flung',
#  'indicates',
#  'rasean',
#  '22,000',
#  'recovery',
#  'carriers',
#  'provide',
#  'rationed',
#  'nuts',
#  'recovers',
#  'shakin',
#  'resignation',
#  '320km',
#  'hfmd',
#  'bares',
#  'fireboy',
#  'chines',
#  'memorial',
#  'customs',
#  'bared',
#  'parry',
#  'arch',
#  'complacent',
#  'treemother',
#  'elusive',
#  'padre',
#  'backwoods',
#  'davies',
#  'upi.',
#  'scalding',
#  '12.3',
#  'kaishek',
#  'innovative',
#  'slimmer',
#  '12.8',
#  'd.phthcria',
#  'christie',
#  'production',
#  'electra',
#  'coffee',
#  'dryrun',
#  'upin',
#  'galorethe',
#  'safe',
#  'collide',
#  'heaven',
#  'reaches',
#  'tmstoi',
#  'lifelong',
#  '7year',
#  'dkgovt',
#  'reasonable',
#  'press\xe2\x80\x94tengku',
#  'feeds',
#  'guidebook',
#  'dumping',
#  '29month',
#  'sles',
#  'slew',
#  '`termite',
#  'raffles',
#  'trainers',
#  'owning',
#  '69,000in',
#  'sampan',
#  'disputed',
#  'barrier',
#  'leftovers',
#  'disputes',
#  'mulley',
#  'forcibly',
#  'mullet',
#  'certified',
#  'maniac',
#  'refugee',
#  'prizetrip',
#  'renew',
#  'footsteps',
#  'stripling',
#  '60ft',
#  '910,000',
#  'champs',
#  'azlan',
#  'another',
#  'rendel',
#  'disembark',
#  'antarctic',
#  'electronic',
#  'mojo',
#  'qults\xe2\x80\x94official',
#  'cabinet\xe2\x80\x94or',
#  'takeovers',
#  'john',
#  'dogs',
#  'emblem',
#  'l/jve',
#  'alonso',
#  'wasted',
#  'dubcek',
#  '1,000th',
#  'guilt',
#  'historical',
#  'anrfjwfewnift',
#  'scans',
#  '210,000',
#  'portraits',
#  'sportsmen',
#  '340,000',
#  'huot',
#  'convenient',
#  'phototherapy',
#  'subjects',
#  'pilgrimage',
#  'unsecured',
#  'likening',
#  'gravy',
#  'nobody',
#  'bruce',
#  'foodnine',
#  'germany',
#  'scripts',
#  'lambton',
#  'germans',
#  'ejector',
#  'swamp',
#  'aunt',
#  '148,000',
#  'reserve',
#  'stephens',
#  'lewis',
#  'tailormade',
#  'twomonthold',
#  'hasegawa',
#  'samboe',
#  'sleuths',
#  'geyser',
#  'em3',
#  'beheads',
#  'kembangan',
#  'haunted',
#  'fawzi',
#  'runs',
#  'mnlf',
#  'krupp',
#  'reintroducing',
#  'emi',
#  'dupont',
#  'gears',
#  'tovtibee',
#  'insurgents',
#  'secretary',
#  '9.30',
#  'daiyu',
#  'dies.',
#  'discussions',
#  'frontline',
#  'techniques',
#  'awar',
#  'pmri',
#  'draws',
#  'nsecrets',
#  'away',
#  'awab',
#  'cooperation',
#  'drawn',
#  'ocbc',
#  'misguided',
#  'shields',
#  'intenetwary',
#  'handful',
#  'exbishop',
#  'flypast',
#  'travellers',
#  'kalmbach',
#  'kitchen',
#  'climate',
#  '11,440',
#  'beuty',
#  'disarms',
#  'utusan',
#  'fags',
#  'filariasis',
#  'tolentino',
#  'disappears',
#  'emporium',
#  'tone',
#  'tong',
#  'toni',
#  'maulding',
#  '2point',
#  'swatuw',
#  'tons',
#  'keppelguangzhou',
#  'exss',
#  'tony',
#  'telecommunications',
#  'priscilla',
#  'gratitude',
#  'noel',
#  'lockup',
#  'superpowers',
#  'attacked',
#  'attacker',
#  'lin\xe2\x80\x94the',
#  'clairvoyant',
#  'armoury',
#  'gracious',
#  'gnp',
#  'reciprocal',
#  'espoused',
#  'barsat',
#  'thrash',
#  'beattheslump',
#  'cons',
#  'vogel',
#  'separatist',
#  'dizzy',
#  'cone',
#  'c.j.',
#  'stransky',
#  'alevel',
#  '160m',
#  'ayub',
#  'exctusive',
#  '\xe2\x82\xacor',
#  'disciplining',
#  'wheel',
#  'fuss',
#  'balkan',
#  'hang',
#  'hand',
#  'liberties',
#  'fuse',
#  'hans',
#  'men\xe2\x80\x94by',
#  'venturing',
#  '1,000no',
#  'humble',
#  'client',
#  'musical',
#  'notsobright',
#  'uniquely',
#  'traditions',
#  'visuallypleasing',
#  'newton',
#  'thanks',
#  'ol',
#  'huldup',
#  'jose',
#  'tramples',
#  'japanchina',
#  'similarities',
#  '14point',
#  'shout',
#  'trampled',
#  'joss',
#  'ussingapore',
#  'fivehour',
#  'openings',
#  'hoists',
#  'celebrates',
#  'everton',
#  'designers',
#  'unfounded',
#  'packin',
#  'cooley',
#  'surgical',
#  'pdip',
#  'homing',
#  'night',
#  'cheongsams',
#  'goatnap',
#  'jobto',
#  '19581031',
#  '19581030',
#  'born',
#  'couture',
#  'bork',
#  'borg',
#  '`red',
#  'confusing',
#  'congratulate',
#  'asking',
#  'lahore',
#  'zanies',
#  'adorable',
#  'participation',
#  'peek',
#  'peel',
#  'ikers',
#  'architectural',
#  'peer',
#  'peep',
#  'herpes',
#  'peet',
#  'xiuwen',
#  'shophouses',
#  'gentler',
#  'wasting',
#  'profession',
#  'attorney',
#  'cholerafree',
#  '21.5',
#  '21.3',
#  'cabfare',
#  'nonmuslims',
#  'conservation',
#  'diligence',
#  'needles',
#  'cedes',
#  'crows',
#  'maximum',
#  'ungle',
#  'heartstrings',
#  'faking',
#  'prayed',
#  'allday',
#  'unleaded',
#  'request',
#  'lidiya',
#  'roneo',
#  'usplane',
#  'prayer',
#  'censute',
#  'test',
#  'langsha',
#  'nonmedical',
#  'fischerkarpov',
#  '22,700',
#  'update',
#  'fin12',
#  '7underpar',
#  'mustdos',
#  'spured',
#  'concorde',
#  'beds',
#  'antimaoist',
#  'knockouts',
#  'songs',
#  'england\xe2\x80\x94by',
#  'concept',
#  'diplomacy',
#  't.u.c.',
#  'stardom\xe2\x80\x94no',
#  'battle',
#  'buslorry',
#  'polluted',
#  'blockedbut',
#  'heller',
#  'zeroing',
#  'aristocratic',
#  '13.8m',
#  'pindling',
#  'treadmill',
#  'nmissile',
#  'turns',
#  'guo',
#  'gun',
#  'gum',
#  'gul',
#  'gus',
#  'urdan',
#  'evades',
#  'evader',
#  'gut',
#  'guy',
#  'alfa',
#  'kedah',
#  'pugilistic',
#  'cost',
#  'rites\xe2\x80\x94for',
#  'forging',
#  '20cm',
#  'cosy',
#  'rapist',
#  '43m',
#  'uery',
#  'shares',
#  'peels',
#  'dutyby',
#  'shared',
#  'goldblum',
#  'gaffar',
#  'scream\xe2\x80\x94',
#  '12,700',
#  'aupe',
#  'strontium',
#  'kenyatta',
#  'sleepwalkers',
#  '9day',
#  'teaches',
#  'teacher',
#  'sociable',
#  'sending',
#  '86,000',
#  'oilfield',
#  'ghows',
#  'preconceptual',
#  'share.',
#  'bangs',
#  '438',
#  '439',
#  '435',
#  'airbase',
#  '433',
#  'drees',
#  'puffer',
#  'most\xe2\x80\x94',
#  'extra',
#  'gunbutt',
#  'uphill',
#  'toteach',
#  'bythesea',
#  'mckenna',
#  'quenching',
#  'driest',
#  'bigs',
#  'yoko',
#  'rainfall',
#  'abrams',
#  'belling',
#  'nguyen',
#  '15,000volt',
#  '61,900',
#  'ibm',
#  'defeats',
#  'fortified',
#  'ibc',
#  'big4',
#  '8,600',
#  'purge',
#  'iby',
#  'trans',
#  'adoptachild',
#  'jordone',
#  'gales',
#  'chip',
#  'chit',
#  'chij',
#  'chin',
#  'chio',
#  'chic',
#  'chia',
#  'lucozade',
#  'alltheway',
#  'strongroom',
#  'spreads',
#  'giveaways',
#  'lounge',
#  'hendrawan',
#  'pmlee',
#  'economy',
#  'armies',
#  'product',
#  'escalate',
#  'fretilin',
#  'produce',
#  'drastic',
#  'ofperak',
#  'noses',
#  'grandson',
#  'tirst',
#  'kurt',
#  'opts',
#  'no.',
#  'serving',
#  'houseboy',
#  'brain',
#  'tablets',
#  'no9',
#  'affirms',
#  'still',
#  'stili',
#  'timsum',
#  'symonds',
#  'facility',
#  'spacious',
#  'bursaries',
#  'tiara',
#  'emigrants',
#  'nol',
#  'non',
#  'noh',
#  'kansom',
#  'nod',
#  'noe',
#  'thermometers',
#  'refineries',
#  'noc',
#  '55,000',
#  'torquay',
#  'wealthy',
#  'thaarup',
#  'nou',
#  'nov',
#  'galloping',
#  'teamy',
#  'drop',
#  '22.6',
#  'vioxx',
#  'magazines',
#  'unloaded',
#  'sot',
#  'aim\xe2\x80\x94to',
#  'grouse',
#  'challenged',
#  'yean',
#  'chamlong',
#  'hitmen',
#  'challenges',
#  'challenger',
#  'replay',
#  'yeap',
#  'year',
#  'shoots',
#  '51m',
#  'bullish',
#  'weiqi',
#  'heldthe',
#  'unwanted',
#  '1847059',
#  'ustaiwan',
#  'tangles',
#  'comment/perspective',
#  'deck',
#  'transition',
#  '519',
#  's4mil.',
#  'tangled',
#  'invitation',
#  '511',
#  '510',
#  'outcry',
#  '512',
#  '517',
#  'blind',
#  'joy\xe2\x80\x94its',
#  'ring',
#  'tame',
#  'tomorrow',
#  'crpri',
#  'caught',
#  'smashup',
#  'brainy',
#  'brains',
#  'appreciates',
#  'camdessus',
#  'pni',
#  'junkyard',
#  'interbank',
#  'png',
#  'professionals',
#  'deluge',
#  '\xe2\x80\x94dog',
#  'recruit',
#  'hsbc',
#  'cockle',
#  'apples',
#  'orwell',
#  'overnight',
#  'oleum',
#  'loke',
#  'ndayhonours',
#  'equipment',
#  'scaring',
#  'threeton',
#  'parly',
#  'polaris',
#  'slimline',
#  'mrt',
#  'implications',
#  'mrs',
#  'ban\xe2\x80\x94',
#  'mra',
#  'discoverer',
#  '3.75',
#  'discovered',
#  'amery',
#  'safeguard',
#  'filipinos',
#  'chopin',
#  'shrill',
#  'wardens',
#  'truffaut',
#  'stroll',
#  '3.7m',
#  'deploredby',
#  'samco',
#  'ambling',
#  'seeni',
#  'spaceeye',
#  'ismay',
#  'burst',
#  'coolingoff',
#  'anchored',
#  'ismal',
#  'samfoo',
#  'debate\xe2\x80\x94now',
#  'suspects',
#  'troubadour',
#  'colours',
#  'gazette',
#  'import',
#  'hartono',
#  'redshirt',
#  'butnottoo',
#  '/a\xc2\xabf',
#  'unbending',
#  'macgillivrays',
#  'hurts',
#  'warhol',
#  'satellitetohome',
#  'manicka',
#  'nile',
#  'templcr',
#  'labours',
#  'madness',
#  'harbouring',
#  'attache',
#  'jeans',
#  'exploit',
#  'oneleg',
#  'newcombe',
#  'muttered',
#  'tropical',
#  'dictator',
#  'lundu',
#  '1030',
#  'ago\xe2\x80\x94a',
#  'ohira',
#  'straying',
#  'pinyin',
#  'fours',
#  'beckenbauer',
#  '13man',
#  'midwives',
#  'suspected',
#  'skiers',
#  'toriesso',
#  'posttsunami',
#  'starstudded',
#  'nevernever',
#  'metric',
#  'dean\xe2\x80\x94no.',
#  'stallbystall',
#  'develop',
#  'evatt',
#  '19581222',
#  'inquiry',
#  '\xc3\x82\xc2\xa325',
#  'frazier',
#  'irline',
#  'foad',
#  'arctic',
#  'foam',
#  '199th',
#  '19581227',
#  '19581204',
#  '19581205',
#  '19581206',
#  '19581207',
#  '19581201',
#  '19581202',
#  '19581203',
#  'onefront',
#  'prenatal',
#  '19581208',
#  '19581209',
#  'squatter',
#  'westin',
#  'congressmen',
#  'taxi',
#  'battleship',
#  'neon',
#  'foot',
#  'maternity',
#  'ozawa',
#  'renewed',
#  'deatn',
#  'caidiao',
#  'ntreaty',
#  'ambushed',
#  'spyros',
#  'pekingjakarta',
#  '1,400',
#  'mman',
#  'halftime',
#  'kwh',
#  'swim',
#  'amk',
#  'psi',
#  'laundering',
#  'swie',
#  'psc',
#  'swig',
#  'psa',
#  'psf',
#  'amy',
#  'earnest',
#  '1956sir',
#  'using',
#  'psv',
#  'stuns',
#  'fortune',
#  'heightened',
#  'conducts',
#  'unspoiled',
#  'haran',
#  'molotov',
#  'output',
#  'twelve',
#  'verbal',
#  'exposed',
#  'tragedies',
#  'inoculatedbut',
#  'envoys',
#  'exposes',
#  'indous',
#  'sporestyle',
#  'kaiser',
#  'dueland',
#  'unlocked',
#  'abalonge',
#  'babysitter',
#  'sumitro',
#  'fractures',
#  'assembly',
#  'sixth',
#  'punched',
#  'fractured',
#  'sixty',
#  'francis',
#  'kawana',
#  'piety',
#  'goodytwoshoes',
#  'aboriginals',
#  'mugging',
#  'macapagal',
#  'lpoh',
#  'intent',
#  'dulles',
#  'backup',
#  'pieta',
#  'freeing',
#  'outlook',
#  'icftu',
#  'shrinking',
#  'intervention',
#  'stare',
#  '15m',
#  'stark',
#  'start',
#  'stars',
#  'starr',
#  'sindbad',
#  'seasoned',
#  'smuggling',
#  'delayed',
#  'rjc',
#  'pitched',
#  'sayyaf',
#  'fraud',
#  'default',
#  'star.',
#  '\xe2\x80\x98we',
#  '600',
#  'jega\xe2\x80\x94an',
#  'currencies',
#  'exsingapore',
#  'quantum',
#  'land\xe2\x80\x94all',
#  'sheath',
#  'redsespecial',
#  'upmarket',
#  'carjack',
#  'trample',
#  'fools',
#  '10,082',
#  'poor',
#  'onestop',
#  '2.8mil',
#  'poof',
#  'registry',
#  '60c',
#  '60b',
#  '60m',
#  'pooh',
#  'poon',
#  'pool',
#  'dabble',
#  'preprimary',
#  'moonlight',
#  'corex',
#  'stockpile',
#  'prying',
#  'homehelp',
#  'overseas',
#  'monte',
#  'ceases',
#  'vr',
#  'month',
#  'unrest',
#  'thoughtful',
#  'religious',
#  'monty',
#  'broadbased',
#  'heliforce',
#  'corps',
#  '\xe2\x80\x94arch',
#  'pledged',
#  'dumpling',
#  'congee',
#  'fountain',
#  'pledges',
#  'twothirds',
#  'resounding',
#  'usjapanchina',
#  'horror',
#  'coloured',
#  'frondizi',
#  'decide',
#  'halftank',
#  '\xe2\x80\x94even',
#  'promao',
#  'vu',
#  'ceaseless',
#  'saboteur',
#  'anan',
#  'borneonisation',
#  'lulls',
#  'streets',
#  'exm.n.p.',
#  'heralds',
#  'outshoots',
#  'hamper',
#  'biafran',
#  'dunn',
#  'ails',
#  'ailu',
#  'investing',
#  'dirt',
#  'learner',
#  'bernhard',
#  'learned',
#  'plessey',
#  'preworld',
#  'tracks',
#  'bribes',
#  'wimbush',
#  '28to4',
#  'excess',
#  'eventful',
#  'zaini\xe2\x80\x94',
#  '\xe2\x80\x94that',
#  'arena',
#  'puskas',
#  'conviction',
#  'inspired',
#  'losses',
#  'first\xe2\x80\x94',
#  'destabilise',
#  'ghafar',
#  'advertising',
#  'macazine',
#  'cathy',
#  'successors',
#  'ail.',
#  'inspires',
#  '700m',
#  'jra',
#  'track4th',
#  'marginal',
#  'put',
#  'jrs',
#  'grundy',
#  'bialoguski',
#  'dowager',
#  'earliest',
#  '4\xc2\xbd',
#  '4\xc2\xbe',
#  'aso',
#  'elmechi',
#  'oecd',
#  'heroic',
#  'taeko',
#  'lowering',
#  'jr.',
#  'outpatient',
#  'dior',
#  'producing',
#  'recreates',
#  'grill',
#  'strangled\xe2\x80\x94with',
#  'directpurchase',
#  'budgets',
#  '740',
#  '743',
#  '747',
#  'afta',
#  'publicise',
#  'overcharging',
#  'rearrests',
#  'caption',
#  'liaison',
#  'unlucky',
#  'ec7858x',
#  'reject',
#  'tengkusgovt',
#  'vigilance',
#  'carco',
#  'businessmen',
#  'nongrads',
#  'oldage',
#  'phatoms',
#  'horizontal',
#  'gunpacking',
#  'undergrads',
#  'sesdaq',
#  'thatshaw',
#  'ringfence',
#  'daggers',
#  'chopsticks',
#  'joget',
#  '1996143',
#  'remnants',
#  'casablanca',
#  'charities',
#  'lovebirds',
#  'icbm',
#  'gunakanlah',
#  'prowler',
#  '60ft.',
#  'wishful',
#  'heron',
#  'absence',
#  '15year',
#  'systems',
#  'friendliest',
#  'evening',
#  'nofault',
#  'ceb',
#  'ceo',
#  'axemen',
#  'starbucks',
#  'permissible',
#  'ninja',
#  'bryan',
#  '450,000',
#  '13,000',
#  'fairs',
#  '2,285',
#  'fairy',
#  'singaporebid',
#  'lifestyles',
#  'heavy',
#  'restless',
#  'funland',
#  'jaws',
#  'house.',
#  'jawi',
#  'heave',
#  'anarchy',
#  'shriver',
#  'jamuna',
#  'marcia',
#  'testify',
#  'jolly',
#  'safety',
#  'blundering',
#  'preying',
#  'citizens\xe2\x80\x94extra',
#  'earns',
#  'houses',
#  'johnnie',
#  'brightest',
#  'takeasean',
#  'threestorey',
#  'turnout',
#  'loads',
#  'allparties',
#  'soyuz10',
#  'leftwing',
#  'due',
#  'byebye',
#  'phonepayment',
#  'quads\xe2\x80\x94but',
#  'ecommerce',
#  'horse',
#  'kodama',
#  'ghaffar',
#  'station',
#  'gibraltar',
#  'hindered',
#  'hundred',
#  'nerdeka',
#  'onoff',
#  'trapped',
#  'year\xe2\x80\x94with',
#  'trapper',
#  'serdang',
#  '1910',
#  '1913',
#  '1914',
#  '1916',
#  'gret',
#  'grew',
#  'grey',
#  'greg',
#  'kishi',
#  'toward',
#  'tganu',
#  'procedural',
#  'bouchard',
#  'phobia',
#  '885',
#  'chu\xc4\x83ng',
#  'lawman',
#  '4member',
#  'perestroika',
#  'null',
#  'organs',
#  'adrift',
#  'salesgirls',
#  'this\xe2\x80\x94a',
#  '50ft.',
#  'wannest',
#  'aired',
#  'hires',
#  'multilingual',
#  'hired',
#  'knotty',
#  '17storey',
#  'privatised',
#  '88m',
#  'tenghui',
#  'tonga',
#  'sturdy',
#  'choonc',
#  'choong',
#  'rockefeller',
#  '7storey',
#  'virata',
#  'qbe',
#  'vitya',
#  'physics',
#  'nations9',
#  'annuities',
#  'quee',
#  'justice',
#  'quer',
#  'upat',
#  'criticising',
#  'tomrt',
#  'wagner',
#  'retorts',
#  'feels',
#  '9820',
#  '126b',
#  'shahbhutto',
#  'imitating',
#  'stopwork',
#  'bovis',
#  'lament',
#  'retaliation',
#  'grocers',
#  'stored',
#  'forster',
#  'dur',
#  'patriotism',
#  '12,300',
#  'culture\xe2\x80\x94by',
#  'culture',
#  'drenching',
#  'inhouse',
#  'today\xe2\x80\x94a',
#  'portrait',
#  'locals',
#  '13nation',
#  'termites',
#  'pictures',
#  'suyin',
#  'uncanny',
#  'missing',
#  'spray',
#  'ranked',
#  'alkaff',
#  'abruptly',
#  'league',
#  'last\xe2\x80\x94colony',
#  'cashing',
#  'minorities',
#  'rehired',
#  'forgotten',
#  'vault',
#  'antipollution',
#  'proton',
#  '258m',
#  'horseowners',
#  'lecturers',
#  'syllabary',
#  'arthit',
#  'threaten',
#  '\xe2\x80\x94china',
#  'empty',
#  'propertytax',
#  'lived',
#  '3organ',
#  'liven',
#  'modelling',
#  'lives',
#  'liver',
#  'oehlers',
#  'affirmative',
#  'pact',
#  'intriguing',
#  'wyatt',
#  'pace',
#  'ought',
#  '3\xc2\xbdhour',
#  '286',
#  'guide',
#  'pack',
#  'costly',
#  'contaminate',
#  'sporebrunei',
#  '00n',
#  'cusack',
#  'communal',
#  'ently',
#  'capital\xe2\x80\x94',
#  'flays',
#  'vulnerable',
#  'grand',
#  'chickenpox',
#  'slanging',
#  'superfast',
#  '\xe2\x80\x94six',
#  'showcased',
#  'fatty',
#  'ratings',
#  '\xe2\x80\x94sir',
#  'blair',
#  'youngsters',
#  '002',
#  '001',
#  '000',
#  '007',
#  '006',
#  'slo.ooo',
#  'filipinoenvoy',
#  'pertama',
#  'poona',
#  'aflutter',
#  'gaddafi',
#  'arshad',
#  'mobs',
#  'speculative',
#  'flaming',
#  'exploits',
#  'raceand',
#  'helmuthaims',
#  'technicians',
#  'reviewed',
#  'chemoil',
#  'mahony',
#  'oporto',
#  'informal',
#  'shortcut',
#  'cherries',
#  'questioned',
#  'newstyle',
#  'rahim',
#  'ight',
#  'showing',
#  'showcases',
#  'dearly',
#  '3139',
#  'ponds',
#  'vests',
#  '127,220',
#  'pipped',
#  'recrea',
#  'eek',
#  'popular',
#  'voted\xe2\x80\x94and',
#  'eec',
#  '\xc3\x82\xc2\xa3100',
#  'sketch',
#  'pedicab',
#  'eurored',
#  'lips',
#  'ailamerican',
#  'aship',
#  'whenspore',
#  'audiovideo',
#  'complain\xe2\x80\x94may',
#  'triads',
#  'lanjutkan',
#  'confounds',
#  'quote',
#  'assistf',
#  'anecdotes',
#  'alive..\xc3\x82\xe2\x80\xa2',
#  'podmore',
#  'gman',
#  'tugof',
#  'viewpoints',
#  's3mil',
#  'lweek',
#  'missingfrom',
#  '254,000',
#  'papua',
#  'silence',
#  '33station',
#  'bangladesh',
#  'placing',
#  'dollarfor',
#  'visas',
#  'spawning',
#  'mulberry',
#  '6,674',
#  'anotherhanoi',
#  'jetsetting',
#  'vacancies',
#  'munir',
#  'mandarinspeaking',
#  'desalination',
#  'similar',
#  'ordered',
#  'gladeye',
#  'recommendation',
#  'ttiieir',
#  'reopening',
#  'proper',
#  'sintok',
#  'ancestors',
#  'mandarinby',
#  'dashed',
#  'fears',
#  'application',
#  'clamours',
#  'department',
#  'dashes',
#  'smiles',
#  'jagan',
#  'jagas',
#  'bigguns',
#  'dvd',
#  'orbit',
#  'bribe',
#  'ignorant',
#  '50.000',
#  'dialformandarin',
#  'k.l.',
#  'offthat',
#  'antiegypt',
#  'compact',
#  '1506347',
#  '8.9m',
#  'nippon',
#  'concessional',
#  'lky',
#  'windsurfer',
#  '15point',
#  'friendly',
#  'pdas',
#  'celebrities',
#  'wave',
#  'starworship',
#  'telling',
#  '_u_k',
#  'oneday',
#  'nsubs',
#  'nausea',
#  'ugandans',
#  'cyberworks',
#  'positions',
#  'michael',
#  'booze',
#  'poreans',
#  'enforce',
#  'maidandboy',
#  '170ft.',
#  'jump',
#  'sultans',
#  'ntalks',
#  '24metre',
#  'vampire',
#  'gen.',
#  'brunei',
#  'warbut',
#  'beijingtoguangzhou',
#  'fifteenth',
#  'radicals',
#  'kidnapped',
#  'firstaid',
#  'stellar',
#  'convert',
#  '1,000member',
#  'parameters',
#  'walkman',
#  'bugis',
#  'gofor',
#  'gene',
#  'salvation',
#  'up\xe2\x80\x94a',
#  'fivedeath',
#  'foresee',
#  'clark',
#  'pinkies',
#  'manage',
#  'clara',
#  'buildup',
#  'suggesions',
#  'zakiah',
#  'frenchmission',
#  'ironwhip',
#  'schumi',
#  'lives\xe2\x80\x94after',
#  'ragstoriches',
#  'camera',
#  'cashback',
#  '595m',
#  'asahi',
#  'isao',
#  '2,975m',
#  'formally',
#  '4.7b',
#  'ecom',
#  'salvager',
#  'charming',
#  'israelis',
#  'rivalry',
#  'appointed',
#  'consort',
#  'kelantan',
#  'recession',
#  'servants',
#  'zailani',
#  'meet',
#  'averages',
#  'bookselling',
#  'links',
#  'kasavubu',
#  'linka',
#  'sought',
#  'muzorewa',
#  'kian',
#  'kiam',
#  '237',
#  'orson',
#  'beinventing',
#  'defective',
#  'iwoman',
#  '230',
#  'sentiments',
#  'kiat',
#  'nara',
#  'fare',
#  'cimema',
#  'farm',
#  'peeling',
#  'expoly',
#  'thunderstorm',
#  'ronald',
#  'aborigines',
#  'matchmaker',
#  'japanus',
#  'iree',
#  'mday',
#  'scoop',
#  'prays',
#  '20gold',
#  's2',
#  'favourites',
#  '3/4',
#  'punggol',
#  'a/c',
#  'including',
#  'costume',
#  'khidmat',
#  'lithuania',
#  'senoko',
#  'gymnasts',
#  '3,000ayear',
#  'gels',
#  'stout',
#  'denand',
#  'university',
#  'sevenmonth',
#  'slide',
#  '3tier',
#  '3room',
#  'expremier',
#  'supermodel',
#  'separating',
#  'mendakiministry',
#  'speciai',
#  'special',
#  'mcmahon',
#  'entertainment',
#  'in\xe2\x80\x94l2',
#  'time.',
#  'sda',
#  'cause',
#  '2985504',
#  'delegates',
#  'achin',
#  'resumed',
#  'i.f.',
#  'fothe',
#  'bridgejump',
#  'maths',
#  'timer',
#  'times',
#  'resumes',
#  'timed',
#  'humphrey',
#  'airgirl',
#  'bemoaning',
#  'powerful',
#  'roundup\xe2\x80\x94and',
#  '101,680',
#  'maoris',
#  'childbashing',
#  'wrapper',
#  'ankle',
#  'chrisiea',
#  'prague',
#  '575,000',
#  'bigcar',
#  'orbitthe',
#  'lists',
#  'chemicals',
#  'coolies',
#  'yips',
#  'newlywed',
#  '20km',
#  'girdle',
#  'thrashing',
#  'elske',
#  'caterer',
#  'midcareer',
#  'enforced',
#  'julian',
#  'horrors',
#  'halal',
#  'newshen',
#  '1,310',
#  '1,319',
#  'battles',
#  'mustapha',
#  'relatives',
#  'battled',
#  'blades',
#  'duels',
#  'sm',
#  'zaini',
#  'discos',
#  'lieut.',
#  'vengeance',
#  'beryl\xe2\x80\x94story',
#  'redbeating',
#  'me\xe2\x80\x94boy',
#  'almostfirst',
#  'gallery',
#  'azmi',
#  'sloo.ooo',
#  'cellphone',
#  'ura',
#  'urn',
#  'indy',
#  'rajas',
#  'astonishing',
#  '4rooiyi',
#  'indo',
#  'paulines',
#  'leejeya',
#  'profitsharing',
#  'halting',
#  'loyaltyand',
#  'higherlevel',
#  'breaktast',
#  'unfinished',
#  'sheriff',
#  'ngo',
#  'brighten',
#  'hector',
#  '8day',
#  'ramasamy',
#  'ayes',
#  'inherited',
#  'mapletree',
#  'topups',
#  'islandwide',
#  'achieve',
#  'kopi',
#  'maritime',
#  'weddomg',
#  'krishen',
#  'tobacco',
#  'aye.',
#  'tuned',
#  'subjected',
#  'tunes',
#  'widow',
#  'armsmaking',
#  'caning',
#  'immigrant',
#  'officials',
#  'reinforcements',
#  'operated',
#  'faros',
#  'luckiest',
#  'nightmare',
#  'teng',
#  'savarkar',
#  'tyre',
#  'tens',
#  '2.4m',
#  'tent',
#  'ken',
#  'tears\xe2\x80\x94and',
#  'mags',
#  'kee',
#  'kea',
#  'interfere',
#  'kicking',
#  'merry',
#  'kew',
#  'ker',
#  'denning',
#  '\xe2\x80\x94new',
#  'sniff',
#  'limits',
#  'olga',
#  '21storey',
#  'strains',
#  'hito',
#  'challenge\xe2\x80\x94maori',
#  'diplomats',
#  'tuesday',
#  'tiredthey',
#  'shenzhou',
#  'armytold',
#  'sparepart',
#  'cent',
#  'outlaws',
#  'immense',
#  'liberals',
#  'whisper',
#  'ufos',
#  'troopers',
#  'controlled',
#  '398,500',
#  'purge\xe2\x80\x94last',
#  'usasia',
#  'controller',
#  'abortions',
#  'smoking',
#  'debtor',
#  '18yearold',
#  'queuing',
#  'dynamism',
#  'backbenchers',
#  'whyatt',
#  'evacuees',
#  'comets',
#  'examines',
#  'surface',
#  'simone',
#  'malays',
#  'haggled',
#  'parts',
#  'speaker',
#  'northwest',
#  'party',
#  'malaya',
#  'stableboy',
#  'yearwe',
#  'banharn',
#  'prored',
#  'selfradicalised',
#  'sibilo',
#  'nobirth',
#  'steals',
#  'rift',
#  '\xe2\x80\x94date',
#  'drowns',
#  'maoists',
#  '44',
#  '\xe2\x80\x94dato',
#  'daim',
#  'discord',
#  'increasingly',
#  'sofia',
#  'oilmen',
#  'ablest',
#  'distant',
#  'advertised',
#  'kljakarta',
#  'hess',
#  'oau',
#  'riverside',
#  'balloons',
#  'disappearance',
#  'clue\xc3\x82\xe2\x80\x94a',
#  'bottoms',
#  'propeller',
#  'loss',
#  'lincoln',
#  'necessary',
#  'lost',
#  'disallows',
#  'roti',
#  'gangsters',
#  'highspeed',
#  'payments',
#  'lose',
#  'ncre',
#  'rote',
#  'climbers',
#  'library',
#  'homi',
#  'home',
#  'britalnus',
#  'halfyearly',
#  'moderates',
#  'pinpoint',
#  'steaming',
#  'broad',
#  'objected',
#  'grinding',
#  'sukiyaki',
#  'wendy',
#  'hartim',
#  'sweepstakes',
#  'wendt',
#  'fanny',
#  'reaching',
#  'traininglearning',
#  'pangkor',
#  'crackshot',
#  'gammell',
#  '90,000',
#  'cropping',
#  'refuge',
#  'nightclub',
#  'muda',
#  'cocos',
#  'pistols',
#  'misty.',
#  'h.g.',
#  'ultrasound',
#  'pointless',
#  'additional',
#  'multistorey',
#  'claras',
#  'north',
#  'mutiny',
#  '946,000',
#  'govtto',
#  'shirle',
#  '533m',
#  'astro',
#  'antipap',
#  'gain',
#  'highest',
#  'rioter',
#  'dies11',
#  'display',
#  'urging',
#  '800m',
#  '800k',
#  'universal',
#  'kisses',
#  'beats',
#  'lumumbaby',
#  'freeforall',
#  'europechina',
#  'education',
#  '8ft',
#  'functions',
#  'ingredients',
#  'entebbe',
#  'kail',
#  'isatype',
#  'yours.',
#  'stat',
#  'elsa',
#  'star',
#  'stay',
#  'stag',
#  'foil',
#  'hivaids',
#  'stab',
#  'sinagapore',
#  'payallgovtbills',
#  'roxette',
#  'shuns',
#  'accidents',
#  'tomcat',
#  'odourfree',
#  'aided',
#  'forgone',
#  'citiraya',
#  'whoops',
#  'sialufthansa',
#  'sichuan',
#  'coffinmaker',
#  's4oo',
#  'aides',
#  'aug',
#  'auf',
#  'swam',
#  'tremors',
#  'swan',
#  'disability',
#  'pensions',
#  'swak',
#  'aun',
#  'painters',
#  'bays',
#  'swap',
#  'malariacarrying',
#  'sorry',
#  'nofood',
#  'sway',
#  'v__v',
#  'abri',
#  'fists',
#  'communique',
#  'void',
#  'lucysilent',
#  'candefeat',
#  'crops',
#  'herbert',
#  'no.5',
#  'no.2',
#  'no.1',
#  'enhance',
#  'stkoop',
#  'whirlwind',
#  'landlords',
#  '2713873',
#  'me.',
#  'exenvoy',
#  'christmas\xe2\x80\x94as',
#  'likely',
#  'muhyiddin',
#  'kidnap',
#  'jordon',
#  'spokesman',
#  'reviving',
#  'mee',
#  'med',
#  'meg',
#  'mec',
#  'mel',
#  'mr.too.',
#  'men',
#  'mei',
#  'meh',
#  'overand',
#  'met',
#  'mew',
#  'jaywalker',
#  'reshuffle',
#  'sporeiraq',
#  '23.46pt',
#  'sandosham',
#  'chrysler',
#  'handwork',
#  'intrigue',
#  'joshua',
#  '\xc2\xa3m',
#  'fantastic',
#  '\xc2\xa3o',
#  'myanmar',
#  'helloo',
#  'grandma',
#  'sevenhour',
#  '\xc2\xa3a',
#  'sliced',
#  'bumpy',
#  'pataudi',
#  'guests',
#  'jackets',
#  'tertiary',
#  'narayan',
#  'runyon',
#  'crash.',
#  'riot\xe2\x80\x942b',
#  'latchkey',
#  'survive',
#  't.t.',
#  'bumpertobumper',
#  'disruption',
#  'berlin',
#  '\xc2\xa34',
#  '\xc2\xa35',
#  '\xc2\xa36',
#  '\xc2\xa37',
#  '\xc2\xa31',
#  '\xc2\xa32',
#  'rook',
#  'room',
#  'wadding',
#  'rood',
#  'roof',
#  'movies',
#  'airindia',
#  'roop',
#  'root',
#  '45month',
#  'unmarked',
#  'climax',
#  '10,000',
#  'foods',
#  'hereone',
#  '68m',
#  'autonomy',
#  'pogo',
#  'initiate',
#  'mcneil',
#  'colds',
#  'hellos',
#  'amazing',
#  'crosswinds',
#  'blanks',
#  'fotkara',
#  'vicious',
#  'egon',
#  'bedok',
#  'schoolchildren',
#  'shantin',
#  'lifesaving',
#  '68.',
#  'third',
#  'descends',
#  'goodbye',
#  '685',
#  '684',
#  'operate',
#  'athletes',
#  'wur',
#  'copters',
#  'sheikhs',
#  'fable',
#  '\xe7\xac\xac1\xe9\xa1\xb5',
#  'saving',
#  'budding',
#  '10.1',
#  '10.2',
#  '10.5',
#  '10.7',
#  'personal',
#  'crew',
#  'g.p.',
#  'stalemate',
#  'schmidt',
#  'gents',
#  'fourway',
#  'anil',
#  'gunning',
#  'parkinson',
#  'stags',
#  'downright',
#  'onethird',
#  'spydar',
#  'randits',
#  'arrested',
#  'curator',
#  'hawkers',
#  'lofty',
#  'calmly',
#  'regionalisation',
#  'aide',
#  'trading',
#  'forgot',
#  'aids',
#  'comedies',
#  'postman',
#  'merchants',
#  'optic',
#  'realtime',
#  'mandy',
#  'lurks',
#  'ripping',
#  'venezuela',
#  'minorityrace',
#  'telecommunication',
#  'resume',
#  'u.s.',
#  'here\xe2\x80\x94magazine',
#  'goalhappy',
#  'aid9',
#  'antidemo',
#  'lotoone',
#  'sixpoint',
#  'grimond',
#  'zapu',
#  'cosmic',
#  '1,126',
#  'leila',
#  '1,120',
#  'vijay',
#  'headway',
#  'force\xe2\x80\x94back',
#  'bionix',
#  '400yearold',
#  'floors',
#  'provencal',
#  'bionic',
#  'feb.',
#  '50tol',
#  'misusing',
#  'hawks',
#  'outat',
#  'bedell',
#  'burgess',
#  'hawke',
#  'stuffed',
#  '2am',
#  'digs',
#  'faceoff',
#  'begins',
#  'yment',
#  'disciplined',
#  '\xe2\x80\x94big',
#  'attlee',
#  'bitterness',
#  'toleratect',
#  'prahus',
#  'bridgepride',
#  'knights',
#  'hailstones',
#  'jeopardise',
#  'palace',
#  'overdependence',
#  'rattle',
#  '12,950',
#  'floodlit',
#  'teamgame',
#  'tells',
#  'sporecomes',
#  'hope\xe2\x80\x94by',
#  'bengal',
#  'fitting',
#  'teagan',
#  'worsening',
#  'tunnels',
#  'yearlong',
#  'blue',
#  'grabovac',
#  'alsagoff',
#  'mario',
#  'doublecrossed',
#  'maria',
#  'zealand',
#  'breather',
#  'worsen',
#  'competitors',
#  '10plus',
#  'rain..',
#  'scotch',
#  'annoyed',
#  'them\xe2\x80\x94say',
#  'brutalities',
#  '4,250',
#  'flouted',
#  '51man',
#  'exarmy',
#  'chatfield',
#  'northeast',
#  'f5s',
#  'jailer',
#  'criedand',
#  'jailed',
#  'b1lingual',
#  'palliative',
#  'praised',
# ...
#  'gusty',
#  'cubans',
#  'georgy',
#  'suspend',
#  'merrill',
#  'surviving',
#  '8digit',
#  'symbolic',
#  'clumsy',
#  'imh',
#  'fetches',
#  'malacca',
#  'george',
#  'trillion',
#  'haggle',
#  'plastic',
#  'sixman',
#  'eartha',
#  'white',
#  'exploring',
#  'mersing',
#  'revue',
#  'season',
#  '9.04',
#  '28.9',
#  '7/8d',
#  '28.3',
#  'stepby',
#  'wide',
#  'poisoning',
#  'marines',
#  'mariner',
#  'cypriots',
#  'bahts',
#  'tarts',
#  'treasurehouse',
#  'confessed',
#  'tarty',
#  'redford',
#  'd.p.p.',
#  'remisier',
#  'cowherd',
#  'prosperity',
#  'conversion',
#  'gantry',
#  'mourners',
#  'alunch',
#  'martinelli',
#  '55th',
#  'multiple',
#  'tornado',
#  'dogfights',
#  'boiling',
#  'oversl3om',
#  'damien.',
#  'discarding',
#  'seafood',
#  'koran',
#  'trafficking',
#  'senior',
#  'swordfighting',
#  'quantity',
#  'shings',
#  'costsharing',
#  'rockfall',
#  'hack',
#  'woos',
#  '12.85',
#  'wood',
#  'woon',
#  'wool',
#  'dreaded',
#  'verdict.',
#  'lighted',
#  'tock',
#  'mistrial',
#  'quintal',
#  'antichina',
#  'sst',
#  'lighten',
#  'expectation',
#  'ssr',
#  'ssl',
#  'sso',
#  'ssh',
#  'lighter',
#  'clerks',
#  'dye',
#  'ssa',
#  'comdex/asia',
#  'jetupandgo',
#  'orphans',
#  'naked',
#  'clowns',
#  'unlicensed',
#  'ignored',
#  'encourages',
#  'ignores',
#  'parking',
#  'stanley',
#  'lng',
#  'antimini',
#  'encouraged',
#  'mortgage',
#  'ways',
#  'review',
#  'spoons',
#  'golfing',
#  'charan',
#  'arrival',
#  'triplespecial',
#  'fearless',
#  'queueing',
#  'twinsfor',
#  'bambee',
#  'fiddling',
#  'overcharge',
#  'mtc',
#  'bambeo',
#  'thrilling',
#  'cities',
#  'come',
#  '\xc2\xa3408',
#  'originates',
#  'reaction',
#  'superstar',
#  'missions',
#  '18year',
#  'allround',
#  'gimmicks',
#  'summu',
#  'columnist',
#  'hourlyrated',
#  'pakistan',
#  'provocation',
#  '20,500',
#  'continuation',
#  '887181',
#  'stripteaser',
#  'kowloon',
#  'fireflies',
#  'skeletons',
#  'raring',
#  'judees',
#  'howard',
#  'eyewitnesses',
#  'memento',
#  'peaceful',
#  'hubbies',
#  'abstract',
#  'followup',
#  'vietnamspore',
#  'ebusiness',
#  'j.p.',
#  'gapby',
#  'allnight',
#  'iritish',
#  'nassim',
#  'shops',
#  'fengshan',
#  'telephone',
#  'dissident',
#  'capping',
#  'redfaced',
#  'reminded',
#  'ethiopia',
#  'bows',
#  'macaroni',
#  'reminder',
#  'physical',
#  '115,500',
#  'hermit',
#  'barefoot',
#  'mockery',
#  'driver',
#  'drives',
#  'muffled',
#  'driven',
#  'submarines',
#  'probella',
#  'sultanso',
#  'clogged',
#  'flybynight',
#  'tebuans',
#  'bourdillon',
#  'bachok',
#  'disloyal',
#  'captures',
#  'boonchu',
#  'djuanda',
#  'lavish',
#  'violent',
#  'kill',
#  'abstained',
#  'kilo',
#  'captured',
#  'blow',
#  'blot',
#  'hint',
#  'antiayub',
#  'multifront',
#  'quitters',
#  'bloodhounds',
#  'blod',
#  'hing',
#  'samples',
#  'hini',
#  'styles',
#  'tsekwang',
#  '32,000',
#  'fridge',
#  'brezhnev',
#  'correcting',
#  'hin1',
#  'eprieve',
#  'egyptlibya',
#  'clays',
#  'shaky',
#  'shunned',
#  'alaqsa',
#  'jjsjjjfi',
#  'madrid',
#  '4thchild',
#  'leadersonly',
#  'divestment',
#  'table',
#  'intact',
#  'slice',
#  'qu.t',
#  'eleanor',
#  'slick',
#  'stops',
#  'footsie',
#  '45,000',
#  'severed',
#  'fables',
#  'inspect',
#  'royals',
#  'loudest',
#  'voracious',
#  'fabled',
#  'rithaudeen',
#  'royale',
#  'baffled',
#  'polity',
#  'stop.',
#  '\xc2\xa3326000',
#  'baffles',
#  'gregory',
#  'accredit',
#  '295m',
#  'holyoake',
#  'cambridge',
#  'jian',
#  'gib.',
#  '236,000',
#  'again\xe2\x80\x94with',
#  'spinal',
#  '1ll',
#  'mcycles',
#  'determine',
#  'lawmaking',
#  'biawak',
#  'distinctions',
#  'hoarding',
#  'pmgoh',
#  'down\xe2\x80\x94tin',
#  'expatriate',
#  'valley',
#  'fish',
#  'catholics',
#  'puisne',
#  'vested',
#  'fundamentals',
#  'cabinet',
#  'milayear',
#  'afast',
#  'powst',
#  'sleazy',
#  'reusing',
#  'chaplin',
#  'toilet',
#  '31hanoi',
#  'cinema',
#  'frighten',
#  'affidavit',
#  'britain',
#  '16page',
#  'spends',
#  '4.5',
#  'cartaxi',
#  '4.6',
#  '4.1',
#  'purdy',
#  '4.3',
#  'igp',
#  'swords',
#  '4.8',
#  'rubber',
#  'dunlops',
#  'igc',
#  'fiddled',
#  'exnepalese',
#  'trash',
#  'stalwart',
#  'championship',
#  'banisadr',
#  'separate',
#  'symbol',
#  'whiskers',
#  'cove',
#  'stocks',
#  'karenthe',
#  'booked',
#  'clinically',
#  'applause',
#  'calls',
#  'sportswoman',
#  '11/2',
#  'mentn',
#  'exhausting',
#  'peninsular',
#  'booker',
#  'childish',
#  'cents\xe2\x80\x94a',
#  'formfilling',
#  'lace',
#  'lack',
#  'frozenegg',
#  'lact',
#  '720,000',
#  'synthetic',
#  'britishiran',
#  '25,360to',
#  'lining',
#  'sparkling',
#  'aaron',
#  'nonaligned',
#  'defuse',
#  'longtime',
#  'urea',
#  'threepart',
#  'chameleon',
#  'far',
#  'fas',
#  'topquality',
#  'grinds',
#  'uren',
#  'fat',
#  'print',
#  'coursing',
#  'sons',
#  'verwoerd',
#  'fam',
#  'fab',
#  'sony',
#  'hemp',
#  'm.for',
#  'shipboard',
#  'stimulus',
#  'stepbystep',
#  'khomeiny',
#  'hifi',
#  'exmajor',
#  'nbi',
#  'resettled',
#  'paralyse',
#  'chng',
#  'anniversary',
#  '216b',
#  'labourparty',
#  'booing',
#  'attitudes',
#  'cinemas',
#  '45minute',
#  'trengganukelantan',
#  '1,692',
#  'maluku',
#  'whitecollar',
#  '4car',
#  'leeds',
#  'relaxation',
#  'wifeswapping',
#  'thrift',
#  'deadheat',
#  'zone',
#  'mousespace',
#  'siamese',
#  'allows',
#  'miniature',
#  'supplements',
#  'runoff',
#  'flightthen',
#  'suddenly',
#  'sixhour',
#  'looked\xe2\x80\x94he',
#  'plonk',
#  'appliances',
#  'outrage\xe2\x80\x94kepala',
#  'wield',
#  'conspiring',
#  'mmc',
#  'brandei',
#  'branded',
#  'grabbing',
#  'operators',
#  'actus',
#  'domination',
#  'keyhole',
#  'stick',
#  'berth',
#  'primate',
#  'tapioca',
#  'intercepted',
#  'perverts',
#  'challenging',
#  '1,500pt',
#  'in\xe2\x80\x94a',
#  '5.3',
#  '5.4',
#  '5.5',
#  '5.6',
#  '5.7',
#  '5.8',
#  'rmn',
#  'speeding',
#  'buzzword',
#  'commotion',
#  'hoaxer',
#  'mould',
#  'singaporeviet',
#  'reflect',
#  'prospecting',
#  'ballads',
#  'rending',
#  'schroders',
#  'gungwu',
#  'exsupp',
#  'departure',
#  'stadiums',
#  'grande',
#  'retaliate',
#  'oneeyed',
#  'ysia',
#  'eludes',
#  'disabled',
#  'quarrels',
#  'littles',
#  'eluded',
#  '49,000',
#  'jackpots',
#  'prodigy',
#  'dodgers\xe2\x80\x94war',
#  'romeoshave',
#  'retta',
#  'merciful',
#  'return',
#  'pingpong',
#  'cdwriter',
#  'framework',
#  '46rr',
#  'malaysiapakistan',
#  'luzi',
#  'milestone',
#  'dehind',
#  'vaughn',
#  '2,600',
#  'hanoiyunnan',
#  'odinga',
#  'holeinone',
#  'shoal',
#  'penance\xe2\x80\x94in',
#  'generation',
#  'pirated',
#  'filmdom',
#  'hartley',
#  '170,000',
#  'lola',
#  'evonne',
#  'lolo',
#  'celebes',
#  'karpov',
#  'comber',
#  'cremated',
#  'threat',
#  'chefs\xe2\x80\x94or',
#  'tebrau',
#  'meridien',
#  'corporals',
#  'there\xe2\x80\x94first',
#  'abrogates',
#  'churning',
#  'fancy',
#  'recains',
#  'tempts',
#  'takeup',
#  'fojund',
#  'wish\xe2\x80\x94',
#  '8group',
#  'scrips',
#  'militant',
#  'script',
#  'gamelan',
#  'financed',
#  'regulation',
#  'shilling',
#  'taxcut',
#  'doomsday',
#  'nian',
#  'passed',
#  'premiers',
#  'syrup',
#  'finances',
#  'headache',
#  'treasured',
#  'option',
#  'cush',
#  'jega',
#  'relieved',
#  'exploded',
#  'from.',
#  'foreigninvestment',
#  'treasures',
#  'convinced',
#  'explodes',
#  'dethrones',
#  '31.68',
#  'double',
#  '31.62',
#  'zainab',
#  'stall',
#  'stalk',
#  'doubly',
#  'dane',
#  'zainal',
#  'cleaner',
#  'imports',
#  'gale',
#  'garfield',
#  'alike',
#  'cleaned',
#  'squints',
#  'exincome',
#  'akai',
#  'lmonth',
#  'airaid',
#  'premter',
#  'ouble',
#  'pianist',
#  'puffing',
#  'soares',
#  'hoff',
#  'reach',
#  'react',
#  'sandra',
#  'seasons',
#  'splat',
#  'achievement',
#  'windows',
#  'doggie',
#  'jeyaretnam',
#  'quotaions',
#  'ingots',
#  'contenders',
#  'mfa',
#  'fong',
#  'fond',
#  'laments',
#  'eightday',
#  'quickoff',
#  'gosouth',
#  'owyang',
#  'firewood',
#  'sporek.l.',
#  'starters',
#  'viagra',
#  'obuchi',
#  'betray',
#  'unilaterally',
#  'gift\xe2\x80\x94a',
#  'mailbag',
#  'hatta',
#  'hip',
#  'thugger',
#  'hit',
#  'psst.',
#  'hiv',
#  'zarbs',
#  'testtubes',
#  'hydrocracker',
#  'hic',
#  '5,000',
#  'kathina',
#  'sumatran',
#  'banquet',
#  'hin',
#  'babytobaby',
#  'cartoons',
#  'tourney',
#  'fishing',
#  'ballerinas',
#  'bars',
#  'baru',
#  'dump',
#  'intelligence',
#  'arc',
#  'dumb',
#  'bard',
#  'arf',
#  'barf',
#  'ari',
#  'bark',
#  'ark',
#  'arm',
#  'learns',
#  'learnt',
#  '\xc2\xa390,000',
#  'distinctive',
#  'libraries',
#  'unions',
#  'various',
#  'plywood',
#  'catandmouse',
#  'consecutive',
#  'twocar',
#  'sporebritain',
#  'penchant',
#  'importers',
#  'opposition',
#  'blazes',
#  'riddled',
#  'became',
#  '8am',
#  'fraternity',
#  'terfu',
#  '1,456',
#  'choleralinked',
#  'finds',
#  'merlion',
#  'hoppe',
#  'improper',
#  'peron',
#  'fibres',
#  'prihatin',
#  'last\xe2\x80\x94the',
#  'suspenders',
#  'rezal',
#  'overlook',
#  'todaiji',
#  'treatments.',
#  'reduction',
#  'mugabe',
#  'slideshow',
#  'simbolon',
#  'fokker',
#  'stolen',
#  'burhanuddin',
#  'awar\xe2\x80\x94by',
#  'm.d.',
#  'mpla',
#  'engineers',
#  'lodges',
#  'gastronomic',
#  'ris',
#  'rip',
#  'irianese',
#  'rio',
#  'rohan',
#  'lodged',
#  'rig',
#  'rid',
#  'anguish',
#  'ethnicity',
#  'lengthy',
#  'widely',
#  'flexitime',
#  'spears',
#  'antisuharto',
#  'quarantinebreaking',
#  '\xc2\xa3lm.',
#  'cheques',
#  'negotiate',
#  'moving',
#  'antibung',
#  'culvert',
#  'posted',
#  'noodle',
#  'analysis',
#  'dared',
#  'edge',
#  'mountbatten',
#  'starved',
#  'oneway',
#  'dares',
#  'hotdog',
#  'petrolpowered',
#  'baluba',
#  'anchoring',
#  'redguns',
#  'vigilant',
#  '174,000',
#  'tamed',
#  'tigress',
#  'flares',
#  'navigator',
#  'tamer',
#  'tames',
#  'familyfriendly',
#  '23cent',
#  'unlimited',
#  '16month',
#  'illfated',
#  'prebudget',
#  'mariam',
#  'marian',
#  'glitters',
#  'capitals',
#  'silkworms',
#  'italians',
#  'pitho',
#  'breeder',
#  'godiva',
#  'liein',
#  'traits',
#  'litter',
#  'vacate',
#  'learnt\xe2\x80\x94by',
#  'guanzhong',
#  '16.97',
#  'pros',
#  'day\xe2\x80\x94and',
#  'prop',
#  'fiveday',
#  'prom',
#  'fatimah',
#  'freed\xe2\x80\x94so',
#  'ticking',
#  'prof',
#  'anne',
#  'prod',
#  'apathetic',
#  'escapefor',
#  'houseinaday',
#  'sexism',
#  'intense',
#  'togetherness',
#  'roundup',
#  'beeline',
#  '152m',
#  'completing',
#  'greets',
#  'hatred',
#  'cutoff',
#  'unnoticed',
#  'conquest',
#  'resilience',
#  'deepfreeze',
#  'amidst',
#  '1,152',
#  'retireat60',
#  '1,150',
#  '1,151',
#  'girlfriends',
#  'varsities',
#  '142,000',
#  'repeatedly',
#  'citytengku',
#  'crane',
#  'calley',
#  'gallantry',
#  'licensees',
#  'declarations',
#  'pira',
#  'called',
#  'shandong',
#  'edberg',
#  'dili',
#  'worthwhile',
#  'soars',
#  'bluechip',
#  'gunpoint',
#  'divisive',
#  'syjvia',
#  'drifts',
#  'guthries',
#  'forestalled',
#  'conies',
#  'tentative',
#  'malicious',
#  'gombak',
#  'bodybuilders',
#  'shylocks',
#  'warplane',
#  '92nd',
#  'baby\xe2\x80\x94and',
#  'viscount',
#  '23,700',
#  '6\xc2\xbdyear',
#  'thames',
#  'scroll',
#  'thirdgeneration',
#  'risis',
#  'philosopher',
#  'adjustment',
#  'contributions',
#  'twotier',
#  'matsumura',
#  'sparrow',
#  'fences',
#  'nothreat',
#  'sniper',
#  'abode',
#  '644m',
#  'tuto',
#  '713',
#  '16.000',
#  'engineered',
#  'leyland',
#  'wishes',
#  'tuts',
#  '10to1',
#  'harlow',
#  'notes',
#  'leader',
#  'deals',
#  'dealt',
#  'outdo',
#  'noted',
#  'claudia',
#  'rri',
#  'plexus',
#  'kiatisuk',
#  'poets',
#  'bodybuilding',
#  'manipulating',
#  'buffeted',
#  'button\xe2\x80\x94by',
#  'gress',
#  'universities',
#  'hourly',
#  'rearming',
#  'waiting',
#  '10,000th',
#  'challe',
#  'attire',
#  'subhas',
#  'ammunition',
#  'sevenpoint',
#  'ladies\xe2\x80\x94by',
#  'tarred',
#  'kegri',
#  'mccity',
#  'scrapped',
#  'cyclist',
#  'metro',
#  'warehousing',
#  'cleopatra',
#  'adjusts',
#  'spiced',
#  'evading',
#  '2,100',
#  'rattan',
#  'lambsdorff',
#  'spices',
#  'higherquality',
#  'apple',
#  'hougang',
#  'scales',
#  'confession',
#  'prapas',
#  'herzog',
#  'motor',
#  'apply',
#  'vellu',
#  'hagerty',
#  'weeping',
#  'december',
#  'automobile',
#  '6p.m.',
#  'cooperate',
#  'rabbit',
#  'penis',
#  'ustralia',
#  'women',
#  'annoy',
#  'slaps',
#  'noncitizens',
#  'splinters',
#  'peopleand',
#  'disconight',
#  'spilled',
#  'proof',
#  'tat',
#  '0.8',
#  'taw',
#  'tap',
#  'tar',
#  'tas',
#  '0.1',
#  'pantymonium',
#  '0.5',
#  'tay',
#  '0.7',
#  'tag',
#  'tab',
#  'serian',
#  'serial',
#  'tao',
#  'tah',
#  'tai',
#  'seatbelts',
#  'ingapore',
#  'guru',
#  'temerloh',
#  'inaugural',
#  'fortunate',
#  '47.9',
#  'cabbies',
#  'usain',
#  'goldsmith',
#  'panic',
#  'exmas',
#  '27,000',
#  '6page',
#  'bestsellers',
#  'salvaging',
#  'perjury',
#  'ethnic',
#  'bursary',
#  '33,460',
#  'sculptures',
#  'interrupted',
#  'nor.i.',
#  'wwii',
#  'crawling',
#  'worksites',
#  'e.h.',
#  'theft',
#  'owl',
#  'sgor',
#  'unjustified',
#  'dearest',
#  'araids',
#  'underwater',
#  'silk',
#  'connors',
#  'choosy',
#  'terriers',
#  'lorryman',
#  'exsgx',
#  'choose',
#  'covered',
#  'bye',
#  'jukebox',
#  'pending',
#  'violating',
#  'crash',
#  'flour',
#  'ntuc',
#  'practice',
#  'quike',
#  'flout',
#  'chandras',
#  'tram',
#  'eased',
#  'fiddle',
#  'trap',
#  'eases',
#  'cigar',
#  'chandran',
#  'stepdown',
#  'ecevit',
#  'siang',
#  'firepower',
#  '88yearold',
#  'respects',
#  'outings',
#  'inchcape',
#  'ioters',
#  'dive',
#  'bhopal',
#  'wcup',
#  'abductor',
#  'york',
#  'conflicts',
#  'yore',
#  'threat\xe2\x80\x94',
#  'kipper',
#  'cair',
#  'fitzpatrick',
#  'feasible',
#  'conversation',
#  'caie',
#  'caid',
#  'adrian',
#  'cain',
#  'reexamines',
#  'tontine',
#  'probation',
#  'destinations',
#  'overtime',
#  'noads',
#  'overdraft',
#  'accent',
#  'donts',
#  'mauritians',
#  'gallen',
#  'frameup',
#  'readybut',
#  'earthshaking',
#  'doomed',
#  'back\xe2\x80\x94for',
#  'greenlight',
#  'died\xe2\x80\x94after',
#  'picturesin',
#  '2,6oo',
#  '257,000',
#  's.s.',
#  'riches',
#  'richer',
#  'tommy',
#  'frugal',
#  'sculpture',
#  '1.4',
#  '1.5',
#  '1.6',
#  '1.7',
#  '1.1',
#  '1.2',
#  '1.3',
#  '1.8',
#  '1.9',
#  'alfonso',
#  'afraid',
#  'barwick',
#  'agency',
#  'zhukov',
#  'spawns',
#  'divers',
#  'skittled',
#  'antialiens',
#  'centre',
#  'onecent',
#  'firecrackers',
#  'tinplate',
#  '1,215',
#  'corneas',
#  'deny',
#  'aidslinked',
#  'dens',
#  'uncompromiding',
#  'dent',
#  'cloaked',
#  'deng',
#  '204,000',
#  'v.c.',
#  'giftoflife',
#  'embassies',
#  'escobar',
#  'osamalinked',
#  'purely',
#  'jiayi',
#  'seaweed',
#  'chicken',
#  'fann',
#  'debate',
#  'hamburglar',
#  'cache',
#  'candidates',
#  'cordobes',
#  '\xc2\xa31.25',
#  'thousands',
#  'colt',
#  'sued',
#  '993',
#  'dope',
#  'camemini',
#  '999',
#  'silat',
#  'ones',
#  'sues',
#  'words',
#  'presley',
#  'suez',
#  'swindle',
#  '\xe2\x80\x94sits.',
#  'vied',
#  '60m.',
#  'viet',
#  'econometric',
#  'prantas',
#  'view',
#  'ebb',
#  'turbulent',
#  '12,017',
#  'merits',
#  'paulson',
#  'violet',
#  '183.5',
#  'gutters',
#  'closer',
#  'closes',
#  'welles',
#  'closet',
#  'superb',
#  'xray',
#  'genius',
#  'mexicans',
#  'ashleigh',
#  'rumblings',
#  'panty',
#  'closed',
#  'chairmen',
#  'oldsters',
#  'pants',
#  'audiovisual',
#  'foetus',
#  'zouk',
#  'huts',
#  'salesgirl',
#  '18.79',
#  'spoil',
#  'mooncake',
#  'addis',
#  'illgotten',
#  'nival',
#  'declining',
#  'barrett',
#  'ingemar',
#  'broadside',
#  'grain',
#  'clansmen',
#  'canopy',
#  'safely',
#  'blandford',
#  'withdraws',
#  'nweapons',
#  'nobuy',
#  'fivenight',
#  'votecatching\xe2\x80\x94sultan',
#  'withdrawn',
#  'unhappiness',
#  'softie',
#  'ghazali',
#  'bbc',
#  'broadcasts',
#  '14storey',
#  '43.4b',
#  'reindeer',
#  'moreforless',
#  'butchers',
#  'historian',
#  'stopped\xe2\x80\x94',
#  'sportsline',
#  'p.i.',
#  'killings',
#  'wily',
#  'bruneians',
#  'irate',
#  'choices',
#  'readies',
#  'wild',
#  'wile',
#  'jehovah',
#  'premier9',
#  'foreign',
#  'day\xe2\x80\x94what',
#  'vintage',
#  'privileges',
#  'adverse',
#  'flower',
#  'hippos',
#  'privileged',
#  'tactful',
#  'premiere',
#  'diploma',
#  '6,596',
#  'fiveminute',
#  'overwork',
#  'implicated',
#  'english',
#  'breaker',
#  'fourpronged',
#  'brumel',
#  'rocket',
#  'percent',
#  'half',
#  'rocked',
#  'aoodbye',
#  'revived\xe2\x80\x94shares',
#  'wogs',
#  'happiness',
#  'serbs',
#  'harare',
#  'sky',
#  'overspending',
#  'sweetener',
#  'hoppy',
#  'adoption',
#  'wearne',
#  'watercooled',
#  'ski',
#  'identical',
#  'sick',
#  'protesters',
#  'republics',
#  'antihanoi',
#  'siemens',
#  'know',
#  'knot',
#  '2.25m',
#  '8,500aday',
#  'taxpayers',
#  'robinho',
#  'hitchhike',
#  'eviction',
#  'roleplay',
#  'subprime',
#  'gravedigger',
#  'lansdowne',
#  'traitors',
#  'searching',
#  '115',
#  '114',
#  '117',
#  '116',
#  '111',
#  '110',
#  '113',
#  '112',
#  'empire',
#  '119',
#  '118',
#  'leaden',
#  'leaf',
#  'lead',
#  'leak',
#  'lean',
#  'leap',
#  '620,000',
#  'nonfinancial',
#  'murdoch',
#  'locate',
#  'mania',
#  'murderer',
#  'poett',
#  'k.i.',
#  '11b',
#  '11m',
#  '11o',
#  'ensures',
#  'murdered',
#  '11p',
#  'wreck\xe2\x80\x94but',
#  'slum',
#  'slug',
#  'mita',
#  'throne',
#  'throng',
#  'getting',
#  'biscuit',
#  'shipping',
#  'surge',
#  'fatally',
#  'seletarmandai',
#  'mediasawy',
#  'warrants',
#  'tummyache',
#  'brush',
#  'registration',
#  'miiister',
#  'significantly',
#  'trawlers',
#  'brundage',
#  'cairn',
#  'kang',
#  '\xe5\xb9\xbf\xe5\x91\x8a',
#  'graftprobe',
#  'appointing',
#  'jury',
#  'funds',
#  'clampdown',
#  'ec',
#  'recede',
#  'wrests',
#  'windfall',
#  '200,000',
#  'cwealth',
#  'china\xe2\x80\x94by',
#  'stratis',
#  'grivas',
#  'heralding',
#  'scepticism',
#  '7death',
#  'itwhat',
#  '12.28',
#  'gnawing',
#  'thurso',
#  'allraces',
#  'ew',
#  'highstakes',
#  'boos',
#  'boot',
#  'illinois',
#  'roars',
#  'book',
#  'haveyou',
#  'boom',
#  'boon',
#  'sicc',
#  'branca',
#  'lance',
#  'junk',
#  'june',
#  'dhou',
#  'dhow',
#  '12.25',
#  'rotting',
#  'expands',
#  'onerace',
#  'footloose']

# %%
[
